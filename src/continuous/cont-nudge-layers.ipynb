# %% [markdown]
# ## sequence is updating the hidden layer

# %% [markdown]
# **State** is (1) gradient and (2) latent space of all layers up to not including output layer, and (3) task identifying information.
#
# **Action** is nxn dimension nudge to layers from -0.01 to 0.01 or -0.001 to 0.001
#
# **Reward** is a difference between developed layer and oracle layer (trained during setup)
#
# Continual learning where it keeps nudging the layer closer to oracle.
#
# Imp'l details
# - train oracle layer in initialization
# - each step, update target layer in self.layers with nudge
# - get difference between target layer being developed and the oracle layer
# - use this differnece as the reward
#
# Less complex than discrete
# - no need for layer pool
# - no need for task enum
# - no need for error conditions and complex action logic

# %%
import math
import copy 
import random
import datetime
from collections import defaultdict
import json
import numpy as np 
import torch
from torch.utils.data import Dataset
from torch.utils.data import DataLoader
import gymnasium
from typing import (
    Type,
    List,
    Tuple,
)
from sb3_contrib import RecurrentPPO
from stable_baselines3 import PPO, A2C, SAC, TD3
import wandb
import matplotlib.pyplot as plt
import scienceplots

plt.style.use(['science','ieee', 'notebook', 'bright'])
plt.rcParams.update({'figure.dpi': '75'})

# %% [markdown]
# ## config

# %%
default_config = {
    'seed' : 41,
    'device' : 'cuda',
    'n_runs' : 1,
    'epochs' : 3,
    'timesteps' : 1000,
    'n_x' : 100,
    'n_tasks' : 2,
    'task_min_loss' : defaultdict(lambda: None),
    'task_max_loss' : defaultdict(lambda: None),
    'in_features' : 1,
    'out_features' : 1,
    'n_hidden_layers_per_network' : 1,
    'n_layers_per_network' : 3,
    'n_nodes_per_layer' : 4,
    'pool_layer_type' : torch.nn.Linear,
    'batch_size' : 100,
    'learning_rate' : 0.01,
    'action_cache_size' : 5,
    'num_workers' : 0,
    'loss_fn' : torch.nn.MSELoss(),
    'sb3_model' : 'PPO',
    'sb3_policy' : 'MlpPolicy',
    'log_dir' : 'wandb',
    }
config = default_config
config['n_pool_hidden_layers'] = config['n_tasks'] * config['n_hidden_layers_per_network']
config
# Out:
# {'seed': 41,
#  'device': 'cuda',
#  'n_runs': 1,
#  'epochs': 3,
#  'timesteps': 1000,
#  'n_x': 100,
#  'n_tasks': 2,
#  'task_min_loss': defaultdict(<function __main__.<lambda>()>, {}),
#  'task_max_loss': defaultdict(<function __main__.<lambda>()>, {}),
#  'in_features': 1,
#  'out_features': 1,
#  'n_hidden_layers_per_network': 1,
#  'n_layers_per_network': 3,
#  'n_nodes_per_layer': 4,
#  'pool_layer_type': torch.nn.modules.linear.Linear,
#  'batch_size': 100,
#  'learning_rate': 0.01,
#  'action_cache_size': 5,
#  'num_workers': 0,
#  'loss_fn': MSELoss(),
#  'sb3_model': 'PPO',
#  'sb3_policy': 'MlpPolicy',
#  'log_dir': 'wandb',
#  'n_pool_hidden_layers': 2}

# %%
wandb.init(
    project='reinforcement-meta-learning',
    config=config
)
# Out:
# Finishing last run (ID:orfl6nsq) before initializing another...
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>cumulative_loss_task0_per_epoch</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▃█▁▁</td></tr><tr><td>cumulative_reward_task0_per_epoch</td><td>████████████████▆▁██</td></tr><tr><td>loss_task0_per_step</td><td>▁▁▁▁▁▁▁▁▁█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>loss_task1_per_step</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▂▂▂▂▁▁▁▁▂▂▄▅▆▇█</td></tr><tr><td>reward_task0_per_step</td><td>█████████▁████████████████████████████▂█</td></tr><tr><td>reward_task1_per_step</td><td>████████████████████████▇▇▆▇▇██▇█▇▇▅▄▃▂▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>cumulative_loss_task0_per_epoch</td><td>6704.28662</td></tr><tr><td>cumulative_reward_task0_per_epoch</td><td>-30707.44531</td></tr><tr><td>loss_task0_per_step</td><td>0.03784</td></tr><tr><td>loss_task1_per_step</td><td>2997.6228</td></tr><tr><td>reward_task0_per_step</td><td>-100.11072</td></tr><tr><td>reward_task1_per_step</td><td>-2997.6228</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">rich-monkey-303</strong> at: <a href='https://wandb.ai/mattstachyra/reinforcement-meta-learning/runs/orfl6nsq' target="_blank">https://wandb.ai/mattstachyra/reinforcement-meta-learning/runs/orfl6nsq</a><br/>Synced 6 W&B file(s), 20 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20231214_153523-orfl6nsq\logs</code>
# Successfully finished last run (ID:orfl6nsq). Initializing new run:<br/>
# wandb version 0.16.1 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.15.12
# Run data is saved locally in <code>c:\Users\stach\Documents\masters-thesis\src\continuous\wandb\run-20231214_170517-6ac1kuyf</code>
# Syncing run <strong><a href='https://wandb.ai/mattstachyra/reinforcement-meta-learning/runs/6ac1kuyf' target="_blank">fancy-snowflake-306</a></strong> to <a href='https://wandb.ai/mattstachyra/reinforcement-meta-learning' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/mattstachyra/reinforcement-meta-learning' target="_blank">https://wandb.ai/mattstachyra/reinforcement-meta-learning</a>
#  View run at <a href='https://wandb.ai/mattstachyra/reinforcement-meta-learning/runs/6ac1kuyf' target="_blank">https://wandb.ai/mattstachyra/reinforcement-meta-learning/runs/6ac1kuyf</a>
# <button onClick="this.nextSibling.style.display='block';this.style.display='none';">Display W&B run</button><iframe src='https://wandb.ai/mattstachyra/reinforcement-meta-learning/runs/6ac1kuyf?jupyter=true' style='border:none;width:100%;height:420px;display:none;'></iframe>

# %%
torch.cuda.is_available()
# Out:
# True

# %% [markdown]
# ### regression
# sinusoidal curve regression as in MAML 2018 paper

# %%
lower_bound = torch.tensor(-5).float()
upper_bound = torch.tensor(5).float()
X = np.linspace(lower_bound, upper_bound, config['n_x'])
amplitude_range = torch.tensor([0.1, 5.0]).float()
phase_range = torch.tensor([0, math.pi]).float()
amps = torch.from_numpy(np.linspace(amplitude_range[0], amplitude_range[1], config['n_tasks'])).float()
phases = torch.from_numpy(np.linspace(phase_range[0], phase_range[1], config['n_tasks'])).float()
tasks_data = torch.tensor(np.array([ 
        X
        for _ in range(config['n_tasks'])
        ])).float()
tasks_targets = torch.tensor(np.array([
        [((a * np.sin(x)) + p).float()
        for x in X] 
        for a, p in zip(amps, phases)
        ])).float()
tasks_info = [
        {'i' : i, 
         'amp' : a, 
         'phase_shift' : p, 
         'lower_bound' : lower_bound, 
         'upper_bound' : upper_bound, 
         'amplitude_range_lower_bound' : amplitude_range[0], 
         'amplitude_range_upper_bound' : amplitude_range[1], 
         'phase_range_lower_bound' : phase_range[0],
         'phase_range_lower_bound' : phase_range[1]}
        for i, (a, p) in enumerate(zip(amps, phases))
]
print(f'[INFO] Tasks created.')
# Out:
# [INFO] Tasks created.

# %%
print(tasks_data.shape)
print(tasks_data.dtype)
print(tasks_targets.shape)
print(tasks_targets.dtype)
print(len(tasks_info))
print(len(tasks_info[0]))
# Out:
# torch.Size([2, 100])
# torch.float32
# torch.Size([2, 100])
# torch.float32
# 2
# 8

# %%
class InnerNetworkTask(Dataset):
    def __init__(self, data, targets, info):
        self.data = data 
        self.targets = targets
        self.info = info

    def __len__(self):
        assert len(self.data) == config['n_x'], '[ERROR] Length should be the same as n_x.'
        return len(self.data)

    def __getitem__(self, index):
        assert self.data[index].dtype == torch.float32, f'[ERROR] Expected type torch.float32, got type: {self.data[index].dtype}'
        assert self.targets[index].dtype == torch.float32, f'[ERROR] Expected type torch.float32, got type: {self.targets[index].dtype}'
        sample = {
            'x' : self.data[index],
            'y' : self.targets[index],
            'info' : self.info
        }
        return sample
    
    def __str__(self):
        return f'[INFO] InnerNetworkTask(data={self.data}, targets={self.targets}, info={self.info})'

# %%
# what the pool has become
initial_input_layer = torch.nn.Linear(in_features=config['in_features'], out_features=config['n_nodes_per_layer'])
initial_hidden_layer = torch.nn.Linear(in_features=config['n_nodes_per_layer'], out_features=config['n_nodes_per_layer'])
initial_output_layer = torch.nn.Linear(in_features=config['n_nodes_per_layer'], out_features=config['out_features'])
torch.nn.init.xavier_uniform_(initial_input_layer.weight)
torch.nn.init.xavier_uniform_(initial_hidden_layer.weight)
torch.nn.init.xavier_uniform_(initial_output_layer.weight)
# Out:
# Parameter containing:
# tensor([[-0.1660, -0.3857,  0.2358, -0.9485]], requires_grad=True)

# %%
class InnerNetwork(gymnasium.Env, torch.nn.Module):
    def __init__(self, 
                task: InnerNetworkTask,
                epoch: int=0,
                in_features: int=config['in_features'],
                out_features: int=config['out_features'],
                learning_rate: float=config['learning_rate'],
                batch_size: int=config['batch_size'],
                action_cache_size: float=config['action_cache_size'],
                num_workers: int=config['num_workers'],
                shuffle: bool=True,
                ):
        super(InnerNetwork, self).__init__()
        self.epoch = epoch
        self.learning_rate = learning_rate
        self.task = task
        self.in_features = in_features
        self.out_features = out_features
        self.batch_size = batch_size
        self.shuffle = shuffle
        self.action_cache_size = action_cache_size
        self.num_workers = num_workers
        
        self.timestep = 0
        self.loss_vals = []
        self.reward_vals = []
        self.prev = defaultdict(lambda: None)
        self.curr = defaultdict(lambda: None)
        self.data_loader = DataLoader(task, batch_size=batch_size, shuffle=shuffle, num_workers=num_workers)
        self.data_iter = iter(self.data_loader)

        # TODO is check whether need to min max scale the reward 
        
        self.initial_input_layer = copy.deepcopy(initial_input_layer)
        self.initial_hidden_layer = copy.deepcopy(initial_hidden_layer)
        self.target_layer = copy.deepcopy(initial_hidden_layer)
        self.initial_output_layer = copy.deepcopy(initial_output_layer)
        self.layers = torch.nn.ModuleList([self.initial_input_layer, self.initial_hidden_layer, self.initial_output_layer]) 
        self.loss_fn = torch.nn.MSELoss()
        self.opt = torch.optim.Adam(self.layers.parameters(), lr=self.learning_rate)

        # create oracle (trained hidden layer) for reward signal
        self.train()
        for _ in range(1000):
            self.next_batch()
            self.opt.zero_grad()
            self.forward(self.curr['x'])
            loss = self.loss_fn(self.curr['y'], self.curr['y_hat'])
            loss.backward()
            self.opt.step()
        self.oracle_layer = self.layers[-2]

        # replace oracle with target 
        self.layers[-2] = self.target_layer

        # check initial loss with target
        self.next_batch()
        self.opt = torch.optim.Adam(self.layers.parameters(), lr=self.learning_rate)
        self.forward(self.curr['x'])
        self.curr['loss'] = self.loss_fn(self.curr['y'], self.curr['y_hat'])
        self.curr['loss'].backward()

        self.observation_space = gymnasium.spaces.box.Box(low=float('-inf'), high=float('inf'), shape=self.build_state().shape)
        # actions are now "steps" so they need to be smaller
        self.action_space = gymnasium.spaces.box.Box(low=-0.1, high=0.1, shape=(config['n_nodes_per_layer'] * config['n_nodes_per_layer'], ), dtype=np.float32)
        print(f"[INFO] Initialized target network for task")

    def step(self, action: np.int64) -> Tuple[torch.Tensor, float, bool, dict]: 
        self.timestep += 1

        # update target layer
        nudges = action
        print(f"weights before={self.target_layer.weight}")
        print(f"nudges={nudges}")
        weights = self.target_layer.weight.reshape((config['n_nodes_per_layer'] * config['n_nodes_per_layer'], ))
        new_weights = weights.detach().numpy() + nudges
        self.target_layer.weight.data = torch.tensor(new_weights).reshape((config['n_nodes_per_layer'], config['n_nodes_per_layer']))
        print(f"weights after={self.target_layer.weight}")
        print()

        # update gradient
        self.prev = self.curr
        self.curr = defaultdict(lambda: None)
        self.next_batch()
        self.train()
        self.opt.zero_grad()
        self.forward(self.curr['x'])
        self.curr['loss'] = self.loss_fn(self.curr['y'], self.curr['y_hat'])
        self.curr['loss'].backward()

        # get next state
        # get learning signal
        # log data
        s_prime = self.build_state() # layer, gradient, task info
        termination = torch.any(torch.abs(self.target_layer.weight.data) > 3)
        learning_signal = self.learning_signal()
        self.log()

        return (
            s_prime,
            learning_signal, 
            termination,
            False,
            {}
        )
            
    def next_batch(self, throw_exception=False) -> None:
        if (throw_exception):
            batch = next(self.data_iter)
            self.curr['x'] = batch['x'].view(-1, 1)
            self.curr['y'] = batch['y'].view(-1, 1)
            self.curr['info'] = batch['info']
        else: 
            try:
                batch = next(self.data_iter)
            except StopIteration:
                self.data_loader = DataLoader(self.task, batch_size=self.batch_size, shuffle=self.shuffle, num_workers=self.num_workers)
                self.data_iter = iter(self.data_loader)
                batch = next(self.data_iter)
            finally:
                self.curr['x'] = batch['x'].view(-1 ,1)
                self.curr['y'] = batch['y'].view(-1, 1)
                self.curr['info'] = batch['info']

    def forward(self, x) -> None:
        for i in range(len(self.layers) - 1): 
            x = torch.nn.functional.relu(self.layers[i](x))
        self.curr['y_hat'] = self.layers[-1](x) 
    
    def build_state(self) -> np.ndarray:
        # characterize the task
        task_info = torch.tensor([self.task.info['amp'], self.task.info['phase_shift']]).squeeze()
        loss = torch.Tensor([self.curr['loss']])
        yhat_scale = torch.Tensor([torch.Tensor(torch.max(torch.abs(self.curr['y_hat']))).detach().item()])
        # get gradient for layer being developed
        gradients = [layer.weight.grad for layer in self.layers]
        gradient = gradients[-2].reshape((config['n_nodes_per_layer'] * config['n_nodes_per_layer'], ))
        # get params of layer being developed
        params = self.layers[-2].weight.reshape((config['n_nodes_per_layer'] * config['n_nodes_per_layer'],))
        
        return torch.concat((
            # target 
            params,

            # helpful info
            # task_info,
            # loss,
            # yhat_scale,
            # gradient,
        ), dim=0).detach().numpy()
    
    def learning_signal(self) -> torch.Tensor: 
        # TODO: try target network's loss
        # TODO: try difference between deltas rather than difference between layers
        # signal = - self.curr['loss']

        loss_fn = torch.nn.MSELoss()
        signal = - loss_fn(self.target_layer.weight.data, self.oracle_layer.weight.data)
        high_magnitude = torch.any(torch.abs(self.target_layer.weight.data) > 3)
        if high_magnitude:
            signal -= 100
        self.curr['reward'] = signal
        
        print(f"[INFO] signal={signal}")
        return signal
        # TODO: try combined learning signal as (difference from oracle) + (loss)

    def log(self):
        task_num = str(self.task.info['i'])
        self.loss_vals.append(copy.copy(self.curr['loss']))
        self.reward_vals.append(copy.copy(self.curr['reward']))
        wandb.log({ f'loss_task{task_num}_per_step' : self.curr['loss']})
        wandb.log({ f'reward_task{task_num}_per_step' : self.curr['reward']})

    def reset(self, seed=None) -> np.ndarray:
        print(f'[INFO] Reset at {self.timestep}')
        self.initial_input_layer = copy.deepcopy(initial_input_layer)
        self.initial_hidden_layer = copy.deepcopy(initial_hidden_layer)
        self.target_layer = copy.deepcopy(initial_hidden_layer)
        self.initial_output_layer = copy.deepcopy(initial_output_layer)
        self.layers = torch.nn.ModuleList([self.initial_input_layer, self.initial_hidden_layer, self.initial_output_layer]) 
        self.loss_fn = torch.nn.MSELoss()
        self.opt = torch.optim.Adam(self.layers.parameters(), lr=self.learning_rate)

        # create oracle (trained hidden layer) for reward signal
        self.train()
        for _ in range(1000):
            self.next_batch()
            self.opt.zero_grad()
            self.forward(self.curr['x'])
            loss = self.loss_fn(self.curr['y'], self.curr['y_hat'])
            loss.backward()
            self.opt.step()
        self.oracle_layer = self.layers[-2]

        # replace oracle with target 
        self.layers[-2] = self.target_layer

        # check initial loss with target
        self.next_batch()
        self.opt = torch.optim.Adam(self.layers.parameters(), lr=self.learning_rate)
        self.forward(self.curr['x'])
        self.curr['loss'] = self.loss_fn(self.curr['y'], self.curr['y_hat'])
        self.curr['loss'].backward()
        return self.build_state(), None

# %%
class REML:
    def __init__(
        self,
        tasks: List[InnerNetworkTask],
        model=config['sb3_model'],
        policy=config['sb3_policy'],
        epochs: int=config['epochs'],
        timesteps: int=config['timesteps'],
        device: str=config['device'],
        log_dir: str=f"./{config['log_dir']}/{config['sb3_model']}_{datetime.datetime.now().strftime('%Y-%m-%d_%H-%M-%S')}"
        ):
        self.tasks = tasks
        if config['sb3_model']=='PPO':
            model = PPO
        elif config['sb3_model']=='RecurrentPPO':
            model = RecurrentPPO
        elif config['sb3_model']=='A2C':
            model = A2C
        dummy_env = self.make_env(tasks[0])
        self.model = SAC(policy, dummy_env, tensorboard_log=log_dir)
        self.policy = policy
        self.epochs = epochs
        self.timesteps = timesteps
        self.device = device # TODO is to check whether cuda is used as assumed
        self.log_dir = log_dir

    
    def __str__(self) -> str:
        return f'REML(model={self.model}, policy={self.policy})'
    
    def make_env(self, task, epoch=None) -> gymnasium.Env:
        return gymnasium.wrappers.NormalizeObservation(InnerNetwork(task, epoch=epoch))

    def train(self):
        # wraps stablebaselines learn() so we call it n * m times
        # n is the number of epochs where we run all m tasks
        # we use the same policy, swapping out envs for the n tasks, m times. 

        # to calculate variance
        # e.g., task: [ n: [epoch: [100 values]] ] / array with n rows, epoch columns 
        # where cell @ [nth run][mth epoch] is cumulative loss/reward
        return_taskkey_epochcol = defaultdict(lambda: [])
        cumuloss_taskkey_epochcol = defaultdict(lambda: [])
        for epoch in range(self.epochs):
            print(f'[INFO] Epoch={epoch + 1}/{self.epochs}')
            for i, task in enumerate(self.tasks): 
                self.task = task
                print(f'[INFO] Task={i+1}/{len(self.tasks)}')

                # each task gets its own network
                self.env = self.make_env(self.task, epoch=epoch)
                self.model.set_env(self.env)
                self.model.learn(total_timesteps=self.timesteps)

                # track reward and loss for plots
                return_taskkey_epochcol[str(self.task.info['i'])].append(sum(self.env.reward_vals))
                cumuloss_taskkey_epochcol[str(self.task.info['i'])].append(sum(self.env.loss_vals))

                # log to wandb
                wandb.log({ f'cumulative_reward_task{i}_per_epoch' : sum(self.env.reward_vals) })
                wandb.log({ f'cumulative_loss_task{i}_per_epoch' : sum(self.env.loss_vals) })

                # sine curves
                self.generate_sine_curve(epoch=epoch, task=i, image=True, title='training_sine_curves', args={'label' : f'task_{i}'})
                
        return return_taskkey_epochcol, cumuloss_taskkey_epochcol
    
    # def evaluate_convergence_speed(self, steps=100) -> dict:
    #     # generates loss curve over 'steps' per task
    #     # TODO is to add option to do so with std if n_runs>1

    #     lossperstep_bytask = defaultdict(lambda: [])

    #     for task in self.tasks: 
    #         env = self.make_env(task)
    #         self.model.set_env(env, force_reset=False)
    #         obs, _ = env.reset()

    #         while len(env.layers) < config['n_layers_per_network']:
    #             action, _ = self.model.predict(obs)
    #             obs, _, _, _, _ = env.step(action)

    #         for _ in range(steps):
    #             action, _ = self.model.predict(obs)
    #             obs, _, _, _, _ = env.step(action)
    #             lossperstep_bytask[task].append(env.curr['loss'])

    #     return lossperstep_bytask

    def generate_sine_curve(self, env=None, data=None, epoch=None, task=None, image=False, new_figures=False, title=None, args=defaultdict()) -> List:
        # generates sine curve after 'env.layers' is full, with option to set env, limit to 
        # subset of env data (for few shot evaluation), and to create png

        # if env is not None:
        #     self.env = env
        #     self.model.set_env(env, force_reset=False)

        # self.env.eval()
        # obs, _ = self.env.reset()
        
        # while len(self.env.layers)!=config['n_layers_per_network']:
        #     action, _ = self.model.predict(obs)
        #     obs, _, _, _, _ = self.env.step(action)
        
        # if data is specified, wrap in new task
        # if data is not specified, the iterator is used over set
        if data is not None:
            dataset = InnerNetworkTask(data=data[:, 0].clone(), targets=data[:, 1].clone(), info=self.task.info)
        else: 
            dataset = self.task

        xs, ys = dataset.data.clone(), dataset.targets.clone()
        xs, ys = xs.view(len(xs), 1), ys.view(len(ys), 1)
        for i in range(len(self.env.layers) - 1): 
            xs = torch.nn.functional.relu(self.env.layers[i](xs))
        yhats = self.env.layers[-1](xs) 

        if new_figures:
            plt.figure()
        plot_title = title if title!=None else f'sine_curve_epoch_{epoch}_task_{task}' if epoch!=None and task!=None else 'sine_curve'
        plot_path = f'{self.log_dir}/{plot_title}.png'  
        plt.plot(dataset.data, [yhat.detach().numpy() for yhat in yhats], **args)
        plt.plot(dataset.data, dataset.targets, label='ground truth', linestyle='--')
        plt.title(plot_title)
        plt.legend()

        if image:
            plt.savefig(plot_path)
            wandb.log({plot_title: wandb.Image(plot_path)})
       
        xs, yhats = dataset.data, [yhat.detach().numpy() for yhat in yhats]
        return xs, yhats

# %% [markdown]
# ### testing

# %%
tasks = [InnerNetworkTask(data=tasks_data[i], targets=tasks_targets[i], info=tasks_info[i]) for i in range(config['n_tasks'])]
eval_task = random.choice(list(tasks))
training_tasks = list(set(tasks) - {eval_task})
reml = REML(tasks=training_tasks)
# Out:
# [INFO] Initialized target network for task

# %%
path = f"meta_{config['sb3_model']}_{datetime.datetime.now().strftime('%H-%M')}"
return_taskkey_nrow_epochcol = defaultdict(lambda: [])
cumuloss_taskkey_nrow_epochcol = defaultdict(lambda: [])

#        epoch1  epoch2  epoch3 ... <- epochs as cols
# task: [return, return, return, ...] 
# task: [cumulative loss, cumulative loss, cumulative loss, ...] 
for n in range(config['n_runs']): 
    print(f"[INFO] n={n+1}")
    return_taskkey_epochvalues, cumuloss_taskkey_epochvalues = reml.train()
    for task in tasks:
        return_taskkey_nrow_epochcol[str(task.info['i'])].append(return_taskkey_epochvalues[str(task.info['i'])])
        cumuloss_taskkey_nrow_epochcol[str(task.info['i'])].append(cumuloss_taskkey_epochvalues[str(task.info['i'])])

# save to json
with open(f'returns_{path}', 'w') as json_file:
    json.dump(return_taskkey_nrow_epochcol, json_file, indent=4)
with open(f'cumuloss_{path}', 'w') as json_file:
    json.dump(cumuloss_taskkey_nrow_epochcol, json_file, indent=4)
# Out:
# [INFO] n=1
# [INFO] Epoch=1/3
# [INFO] Task=1/1
# [INFO] Initialized target network for task
# [INFO] Reset at 0
# weights before=Parameter containing:
# tensor([[-0.7951,  0.6267, -0.8307, -0.7619],
#         [-0.3047,  0.4708, -0.1719,  0.8580],
#         [-0.1162,  0.4736, -0.5573, -0.4005],
#         [ 0.2186,  0.2895, -0.1463, -0.2233]], requires_grad=True)
# nudges=[ 0.02056923  0.07541253 -0.0338899  -0.02612297  0.00858621 -0.09026112
#   0.09772592  0.09210934  0.08166606  0.06629644 -0.05115603  0.04367546
#   0.05430412 -0.04125778 -0.06207305  0.0731343 ]
# weights after=Parameter containing:
# tensor([[-0.7746,  0.7021, -0.8646, -0.7880],
#         [-0.2961,  0.3805, -0.0742,  0.9501],
#         [-0.0345,  0.5399, -0.6085, -0.3568],
#         [ 0.2729,  0.2483, -0.2083, -0.1502]], requires_grad=True)
#
# [INFO] signal=-0.944596529006958
# weights before=Parameter containing:
# tensor([[-0.7746,  0.7021, -0.8646, -0.7880],
#         [-0.2961,  0.3805, -0.0742,  0.9501],
#         [-0.0345,  0.5399, -0.6085, -0.3568],
#         [ 0.2729,  0.2483, -0.2083, -0.1502]], requires_grad=True)
# nudges=[-0.06609528 -0.07767637 -0.06218375 -0.07337195 -0.06747809 -0.09772825
#  -0.0509922   0.00521455  0.07231834  0.09351801 -0.00964054  0.08987414
#   0.01070644  0.00104661  0.07026257 -0.04477289]
# weights after=Parameter containing:
# tensor([[-0.8407,  0.6244, -0.9268, -0.8614],
#         [-0.3636,  0.2828, -0.1252,  0.9553],
#         [ 0.0378,  0.6334, -0.6181, -0.2669],
#         [ 0.2836,  0.2493, -0.1381, -0.1950]], requires_grad=True)
#
# [INFO] signal=-0.9272534251213074
# weights before=Parameter containing:
# tensor([[-0.8407,  0.6244, -0.9268, -0.8614],
#         [-0.3636,  0.2828, -0.1252,  0.9553],
#         [ 0.0378,  0.6334, -0.6181, -0.2669],
#         [ 0.2836,  0.2493, -0.1381, -0.1950]], requires_grad=True)
# nudges=[-0.0280643   0.08910912  0.00789203  0.06012101 -0.02834871 -0.09168494
#  -0.04265631 -0.01312179  0.07972883 -0.02042181 -0.02529874 -0.0936249
#   0.09524208  0.01384884  0.03241693 -0.02979734]
# weights after=Parameter containing:
# tensor([[-0.8687,  0.7135, -0.9189, -0.8013],
#         [-0.3919,  0.1911, -0.1678,  0.9422],
#         [ 0.1175,  0.6130, -0.6434, -0.3606],
#         [ 0.3788,  0.2632, -0.1057, -0.2248]], requires_grad=True)
#
# [INFO] signal=-0.9145523309707642
# weights before=Parameter containing:
# tensor([[-0.8687,  0.7135, -0.9189, -0.8013],
#         [-0.3919,  0.1911, -0.1678,  0.9422],
#         [ 0.1175,  0.6130, -0.6434, -0.3606],
#         [ 0.3788,  0.2632, -0.1057, -0.2248]], requires_grad=True)
# nudges=[-0.02240136 -0.00744896  0.07466011 -0.05636966  0.03656911 -0.08775627
#  -0.09422889  0.0254719  -0.08814391  0.05952115 -0.03180091  0.05717627
#  -0.05311452  0.02805153  0.03830969  0.01238873]
# weights after=Parameter containing:
# tensor([[-0.8911,  0.7061, -0.8442, -0.8576],
#         [-0.3553,  0.1033, -0.2620,  0.9676],
#         [ 0.0294,  0.6725, -0.6752, -0.3034],
#         [ 0.3257,  0.2912, -0.0674, -0.2124]], requires_grad=True)
#
# [INFO] signal=-0.8707517981529236
# weights before=Parameter containing:
# tensor([[-0.8911,  0.7061, -0.8442, -0.8576],
#         [-0.3553,  0.1033, -0.2620,  0.9676],
#         [ 0.0294,  0.6725, -0.6752, -0.3034],
#         [ 0.3257,  0.2912, -0.0674, -0.2124]], requires_grad=True)
# nudges=[ 0.07413677  0.00733036 -0.07261138 -0.01635445 -0.04590849  0.04074091
#   0.01048843  0.0710237  -0.06171695 -0.00576428  0.06116503  0.0109119
#  -0.08995683  0.06312718  0.05614071 -0.04470033]
# weights after=Parameter containing:
# tensor([[-0.8170,  0.7134, -0.9168, -0.8740],
#         [-0.4013,  0.1441, -0.2516,  1.0387],
#         [-0.0324,  0.6667, -0.6141, -0.2925],
#         [ 0.2358,  0.3543, -0.0112, -0.2571]], requires_grad=True)
#
# [INFO] signal=-0.871372640132904
# [INFO] Reset at 5
# weights before=Parameter containing:
# tensor([[-0.7951,  0.6267, -0.8307, -0.7619],
#         [-0.3047,  0.4708, -0.1719,  0.8580],
#         [-0.1162,  0.4736, -0.5573, -0.4005],
#         [ 0.2186,  0.2895, -0.1463, -0.2233]], requires_grad=True)
# nudges=[ 0.05988946  0.08123072 -0.02391822 -0.07765928 -0.05921867 -0.09834231
#  -0.03440139  0.08837511  0.04870858 -0.00956964  0.01840129 -0.02746721
#   0.06326469 -0.03972777 -0.03550433  0.046725  ]
# weights after=Parameter containing:
# tensor([[-0.7352,  0.7079, -0.8546, -0.8395],
#         [-0.3639,  0.3724, -0.2063,  0.9463],
#         [-0.0675,  0.4640, -0.5389, -0.4279],
#         [ 0.2819,  0.2498, -0.1818, -0.1766]], requires_grad=True)
#
# [INFO] signal=-0.8838333487510681
# weights before=Parameter containing:
# tensor([[-0.7352,  0.7079, -0.8546, -0.8395],
#         [-0.3639,  0.3724, -0.2063,  0.9463],
#         [-0.0675,  0.4640, -0.5389, -0.4279],
#         [ 0.2819,  0.2498, -0.1818, -0.1766]], requires_grad=True)
# nudges=[-0.04352499  0.09546869  0.08763211 -0.04946135 -0.03468034  0.01158036
#   0.09501015  0.08940607  0.08775934  0.08370767 -0.02740064 -0.04776908
#  -0.07139768 -0.00251392 -0.00031204 -0.00266819]
# weights after=Parameter containing:
# tensor([[-0.7788,  0.8034, -0.7670, -0.8890],
#         [-0.3986,  0.3840, -0.1113,  1.0357],
#         [ 0.0203,  0.5477, -0.5663, -0.4757],
#         [ 0.2105,  0.2473, -0.1821, -0.1793]], requires_grad=True)
#
# [INFO] signal=-0.9290904998779297
# [INFO] Reset at 7
# weights before=Parameter containing:
# tensor([[-0.7951,  0.6267, -0.8307, -0.7619],
#         [-0.3047,  0.4708, -0.1719,  0.8580],
#         [-0.1162,  0.4736, -0.5573, -0.4005],
#         [ 0.2186,  0.2895, -0.1463, -0.2233]], requires_grad=True)
# nudges=[ 0.07571556  0.05066264  0.09674653  0.01163585 -0.009161    0.03158278
#  -0.054615    0.06119194  0.01286288  0.01119576  0.00119574 -0.070388
#   0.04515349 -0.01124311 -0.02389371  0.00802686]
# weights after=Parameter containing:
# tensor([[-0.7194,  0.6773, -0.7340, -0.7502],
#         [-0.3138,  0.5024, -0.2265,  0.9192],
#         [-0.1033,  0.4848, -0.5561, -0.4709],
#         [ 0.2637,  0.2783, -0.1702, -0.2153]], requires_grad=True)
#
# [INFO] signal=-0.8740360736846924
# weights before=Parameter containing:
# tensor([[-0.7194,  0.6773, -0.7340, -0.7502],
#         [-0.3138,  0.5024, -0.2265,  0.9192],
#         [-0.1033,  0.4848, -0.5561, -0.4709],
#         [ 0.2637,  0.2783, -0.1702, -0.2153]], requires_grad=True)
# nudges=[-0.07742312 -0.07428835 -0.03662663  0.02507091 -0.08263112  0.09346431
#  -0.05445899  0.06813315 -0.02436347  0.0072384  -0.00073068 -0.04694838
#   0.00284003  0.01983581  0.07549091 -0.0449103 ]
# weights after=Parameter containing:
# tensor([[-0.7968,  0.6030, -0.7706, -0.7252],
#         [-0.3965,  0.5958, -0.2810,  0.9873],
#         [-0.1277,  0.4920, -0.5569, -0.5178],
#         [ 0.2666,  0.2981, -0.0947, -0.2602]], requires_grad=True)
#
# [INFO] signal=-0.8523383736610413
# weights before=Parameter containing:
# tensor([[-0.7968,  0.6030, -0.7706, -0.7252],
#         [-0.3965,  0.5958, -0.2810,  0.9873],
#         [-0.1277,  0.4920, -0.5569, -0.5178],
#         [ 0.2666,  0.2981, -0.0947, -0.2602]], requires_grad=True)
# nudges=[ 0.03428856 -0.09327921 -0.01041646 -0.03995783 -0.04580519 -0.04710491
#  -0.00932062 -0.03170339 -0.0677512   0.0315743  -0.08478841  0.03226911
#   0.04108272 -0.06668822 -0.08244646 -0.06163836]
# weights after=Parameter containing:
# tensor([[-0.7625,  0.5098, -0.7810, -0.7651],
#         [-0.4423,  0.5487, -0.2903,  0.9556],
#         [-0.1955,  0.5236, -0.6416, -0.4855],
#         [ 0.3077,  0.2314, -0.1771, -0.3219]], requires_grad=True)
#
# [INFO] signal=-0.8497559428215027
# weights before=Parameter containing:
# tensor([[-0.7625,  0.5098, -0.7810, -0.7651],
#         [-0.4423,  0.5487, -0.2903,  0.9556],
#         [-0.1955,  0.5236, -0.6416, -0.4855],
#         [ 0.3077,  0.2314, -0.1771, -0.3219]], requires_grad=True)
# nudges=[ 0.04977778  0.02257893 -0.09472492 -0.03284963  0.00105139 -0.07781506
#  -0.08030262  0.06643317  0.01697948  0.09430801 -0.02684659  0.09019332
#   0.01788292  0.0963321   0.04218211  0.00313135]
# weights after=Parameter containing:
# tensor([[-0.7128,  0.5323, -0.8757, -0.7980],
#         [-0.4412,  0.4709, -0.3706,  1.0220],
#         [-0.1785,  0.6179, -0.6685, -0.3954],
#         [ 0.3256,  0.3278, -0.1349, -0.3187]], requires_grad=True)
#
# [INFO] signal=-0.8127498626708984
# [INFO] Reset at 11
# weights before=Parameter containing:
# tensor([[-0.7951,  0.6267, -0.8307, -0.7619],
#         [-0.3047,  0.4708, -0.1719,  0.8580],
#         [-0.1162,  0.4736, -0.5573, -0.4005],
#         [ 0.2186,  0.2895, -0.1463, -0.2233]], requires_grad=True)
# nudges=[-0.0349673  -0.0469744  -0.01830642  0.04100137 -0.065022   -0.00947906
#  -0.05772815 -0.09949113 -0.09567158 -0.0357769  -0.01742565 -0.04784932
#  -0.07084458 -0.09155079 -0.03021513  0.0560888 ]
# weights after=Parameter containing:
# tensor([[-0.8301,  0.5797, -0.8490, -0.7209],
#         [-0.3697,  0.4613, -0.2296,  0.7585],
#         [-0.2119,  0.4378, -0.5748, -0.4483],
#         [ 0.1478,  0.1980, -0.1765, -0.1673]], requires_grad=True)
#
# [INFO] signal=-0.8801297545433044
# weights before=Parameter containing:
# tensor([[-0.8301,  0.5797, -0.8490, -0.7209],
#         [-0.3697,  0.4613, -0.2296,  0.7585],
#         [-0.2119,  0.4378, -0.5748, -0.4483],
#         [ 0.1478,  0.1980, -0.1765, -0.1673]], requires_grad=True)
# nudges=[-0.03830836  0.09845824 -0.05696576 -0.02464332  0.07073464  0.05620516
#   0.02628183 -0.05242995 -0.0752919   0.03288528  0.04423048 -0.07124788
#   0.00488187 -0.01663236  0.02623548 -0.05540634]
# weights after=Parameter containing:
# tensor([[-0.8684,  0.6782, -0.9060, -0.7455],
#         [-0.2990,  0.5175, -0.2033,  0.7060],
#         [-0.2872,  0.4707, -0.5305, -0.5196],
#         [ 0.1526,  0.1813, -0.1502, -0.2227]], requires_grad=True)
#
# [INFO] signal=-0.896526575088501
# weights before=Parameter containing:
# tensor([[-0.8684,  0.6782, -0.9060, -0.7455],
#         [-0.2990,  0.5175, -0.2033,  0.7060],
#         [-0.2872,  0.4707, -0.5305, -0.5196],
#         [ 0.1526,  0.1813, -0.1502, -0.2227]], requires_grad=True)
# nudges=[ 0.05739588  0.07645001  0.08917468 -0.03317319  0.09730735  0.04566442
#  -0.07107044 -0.09069797  0.09469599 -0.00717521  0.08961808  0.04923045
#   0.02088932 -0.09887369  0.00234827  0.00118516]
# weights after=Parameter containing:
# tensor([[-0.8110,  0.7546, -0.8168, -0.7787],
#         [-0.2017,  0.5632, -0.2744,  0.6153],
#         [-0.1925,  0.4635, -0.4409, -0.4703],
#         [ 0.1735,  0.0825, -0.1479, -0.2215]], requires_grad=True)
#
# [INFO] signal=-0.8707373738288879
# weights before=Parameter containing:
# tensor([[-0.8110,  0.7546, -0.8168, -0.7787],
#         [-0.2017,  0.5632, -0.2744,  0.6153],
#         [-0.1925,  0.4635, -0.4409, -0.4703],
#         [ 0.1735,  0.0825, -0.1479, -0.2215]], requires_grad=True)
# nudges=[-0.05008087  0.09759741 -0.08354361  0.08483293  0.01688948 -0.04465411
#  -0.08706097 -0.07404204 -0.04136325 -0.08117053 -0.06617953 -0.00476291
#  -0.06280236  0.0130868   0.01795119 -0.08584935]
# weights after=Parameter containing:
# tensor([[-0.8611,  0.8522, -0.9003, -0.6939],
#         [-0.1848,  0.5185, -0.3615,  0.5413],
#         [-0.2338,  0.3823, -0.5071, -0.4751],
#         [ 0.1107,  0.0956, -0.1300, -0.3073]], requires_grad=True)
#
# [INFO] signal=-0.8378161787986755
# weights before=Parameter containing:
# tensor([[-0.8611,  0.8522, -0.9003, -0.6939],
#         [-0.1848,  0.5185, -0.3615,  0.5413],
#         [-0.2338,  0.3823, -0.5071, -0.4751],
#         [ 0.1107,  0.0956, -0.1300, -0.3073]], requires_grad=True)
# nudges=[ 0.00463632 -0.03196164 -0.05077298  0.04324783  0.03985231 -0.08594418
#   0.00725047  0.04162999 -0.09618689 -0.02308131  0.0740437   0.0478726
#   0.09491091 -0.07084069  0.09680738 -0.06309596]
# weights after=Parameter containing:
# tensor([[-0.8565,  0.8202, -0.9511, -0.6506],
#         [-0.1449,  0.4326, -0.3542,  0.5829],
#         [-0.3300,  0.3593, -0.4330, -0.4272],
#         [ 0.2056,  0.0247, -0.0331, -0.3704]], requires_grad=True)
#
# [INFO] signal=-0.8455265760421753
# weights before=Parameter containing:
# tensor([[-0.8565,  0.8202, -0.9511, -0.6506],
#         [-0.1449,  0.4326, -0.3542,  0.5829],
#         [-0.3300,  0.3593, -0.4330, -0.4272],
#         [ 0.2056,  0.0247, -0.0331, -0.3704]], requires_grad=True)
# nudges=[-0.04103161 -0.09603203 -0.02438162 -0.04239185 -0.06548734 -0.03103485
#   0.00296201  0.01278482 -0.00998365 -0.07137386  0.00372289 -0.08990078
#  -0.0404433  -0.07211155 -0.05779954  0.01596282]
# weights after=Parameter containing:
# tensor([[-0.8975,  0.7242, -0.9755, -0.6930],
#         [-0.2104,  0.4015, -0.3513,  0.5957],
#         [-0.3400,  0.2879, -0.4293, -0.5171],
#         [ 0.1652, -0.0474, -0.0909, -0.3545]], requires_grad=True)
#
# [INFO] signal=-0.8472662568092346
# weights before=Parameter containing:
# tensor([[-0.8975,  0.7242, -0.9755, -0.6930],
#         [-0.2104,  0.4015, -0.3513,  0.5957],
#         [-0.3400,  0.2879, -0.4293, -0.5171],
#         [ 0.1652, -0.0474, -0.0909, -0.3545]], requires_grad=True)
# nudges=[-0.05986534  0.04792332 -0.03896112 -0.04564599  0.03409123 -0.02537154
#   0.09078281 -0.04784344 -0.0547917   0.01690678  0.00102763  0.00441335
#   0.06129719 -0.05437462 -0.01419357 -0.05129588]
# weights after=Parameter containing:
# tensor([[-0.9573,  0.7721, -1.0145, -0.7387],
#         [-0.1763,  0.3762, -0.2605,  0.5479],
#         [-0.3948,  0.3048, -0.4283, -0.5127],
#         [ 0.2265, -0.1018, -0.1051, -0.4058]], requires_grad=True)
#
# [INFO] signal=-0.8987579941749573
# [INFO] Reset at 18
# weights before=Parameter containing:
# tensor([[-0.7951,  0.6267, -0.8307, -0.7619],
#         [-0.3047,  0.4708, -0.1719,  0.8580],
#         [-0.1162,  0.4736, -0.5573, -0.4005],
#         [ 0.2186,  0.2895, -0.1463, -0.2233]], requires_grad=True)
# nudges=[ 0.04013563  0.07538103  0.00553127 -0.0675609   0.03384217 -0.04392866
#  -0.02587244 -0.07669722  0.0399851   0.03934144  0.08309516  0.03415547
#  -0.09745335  0.00880035  0.04169791  0.09937697]
# weights after=Parameter containing:
# tensor([[-0.7550,  0.7021, -0.8252, -0.8294],
#         [-0.2708,  0.4268, -0.1978,  0.7813],
#         [-0.0762,  0.5129, -0.4742, -0.3663],
#         [ 0.1211,  0.2983, -0.1046, -0.1240]], requires_grad=True)
#
# [INFO] signal=-0.8931869864463806
# weights before=Parameter containing:
# tensor([[-0.7550,  0.7021, -0.8252, -0.8294],
#         [-0.2708,  0.4268, -0.1978,  0.7813],
#         [-0.0762,  0.5129, -0.4742, -0.3663],
#         [ 0.1211,  0.2983, -0.1046, -0.1240]], requires_grad=True)
# nudges=[ 0.03700631 -0.00293809 -0.02455387  0.03166833  0.08236683  0.094115
#   0.00020117 -0.03548365  0.07848293 -0.0274331   0.0997267  -0.07980231
#  -0.0671691   0.06120441  0.08785114  0.08228507]
# weights after=Parameter containing:
# tensor([[-0.7180,  0.6991, -0.8497, -0.7978],
#         [-0.1885,  0.5210, -0.1976,  0.7458],
#         [ 0.0023,  0.4855, -0.3745, -0.4461],
#         [ 0.0540,  0.3595, -0.0167, -0.0417]], requires_grad=True)
#
# [INFO] signal=-0.903672456741333
# weights before=Parameter containing:
# tensor([[-0.7180,  0.6991, -0.8497, -0.7978],
#         [-0.1885,  0.5210, -0.1976,  0.7458],
#         [ 0.0023,  0.4855, -0.3745, -0.4461],
#         [ 0.0540,  0.3595, -0.0167, -0.0417]], requires_grad=True)
# nudges=[ 0.03783015  0.03195477  0.04945505  0.02255155 -0.04622294  0.07418213
#  -0.09999485  0.02704101  0.09264386  0.08196891 -0.08685002 -0.06553419
#  -0.02274296  0.01123562  0.03834058 -0.06279281]
# weights after=Parameter containing:
# tensor([[-0.6802,  0.7311, -0.8003, -0.7752],
#         [-0.2347,  0.5951, -0.2976,  0.7728],
#         [ 0.0949,  0.5675, -0.4614, -0.5117],
#         [ 0.0312,  0.3708,  0.0216, -0.1045]], requires_grad=True)
#
# [INFO] signal=-0.8601229190826416
# weights before=Parameter containing:
# tensor([[-0.6802,  0.7311, -0.8003, -0.7752],
#         [-0.2347,  0.5951, -0.2976,  0.7728],
#         [ 0.0949,  0.5675, -0.4614, -0.5117],
#         [ 0.0312,  0.3708,  0.0216, -0.1045]], requires_grad=True)
# nudges=[-0.09921813  0.02822962 -0.0665545   0.08008613 -0.07912589  0.04766037
#   0.06697681 -0.07984921  0.09138497  0.02664059  0.06996123 -0.06448482
#  -0.01436196  0.01439174 -0.00611265 -0.05887851]
# weights after=Parameter containing:
# tensor([[-0.7794,  0.7593, -0.8668, -0.6951],
#         [-0.3138,  0.6428, -0.2306,  0.6930],
#         [ 0.1863,  0.5941, -0.3914, -0.5761],
#         [ 0.0169,  0.3852,  0.0155, -0.1634]], requires_grad=True)
#
# [INFO] signal=-0.9024452567100525
# weights before=Parameter containing:
# tensor([[-0.7794,  0.7593, -0.8668, -0.6951],
#         [-0.3138,  0.6428, -0.2306,  0.6930],
#         [ 0.1863,  0.5941, -0.3914, -0.5761],
#         [ 0.0169,  0.3852,  0.0155, -0.1634]], requires_grad=True)
# nudges=[-0.01175978  0.07956941  0.08324956 -0.06653707  0.01075884  0.02665804
#  -0.03846968  0.09312584  0.01015203 -0.03106734 -0.0123897  -0.09319126
#   0.02533583 -0.00297804 -0.04089352 -0.07475587]
# weights after=Parameter containing:
# tensor([[-0.7911,  0.8389, -0.7836, -0.7617],
#         [-0.3031,  0.6695, -0.2690,  0.7861],
#         [ 0.1964,  0.5630, -0.4038, -0.6693],
#         [ 0.0422,  0.3822, -0.0254, -0.2381]], requires_grad=True)
#
# [INFO] signal=-0.8802500367164612
# weights before=Parameter containing:
# tensor([[-0.7911,  0.8389, -0.7836, -0.7617],
#         [-0.3031,  0.6695, -0.2690,  0.7861],
#         [ 0.1964,  0.5630, -0.4038, -0.6693],
#         [ 0.0422,  0.3822, -0.0254, -0.2381]], requires_grad=True)
# nudges=[-0.03674795  0.01286362 -0.0643276  -0.06887712 -0.09861111 -0.08346054
#   0.03103905  0.09223505  0.07648175  0.00844911 -0.05879082 -0.04137415
#  -0.00755943 -0.06519157  0.04872765 -0.0765068 ]
# weights after=Parameter containing:
# tensor([[-0.8279,  0.8517, -0.8479, -0.8306],
#         [-0.4017,  0.5860, -0.2380,  0.8783],
#         [ 0.2729,  0.5715, -0.4626, -0.7107],
#         [ 0.0346,  0.3170,  0.0233, -0.3146]], requires_grad=True)
#
# [INFO] signal=-0.8955550193786621
# weights before=Parameter containing:
# tensor([[-0.8279,  0.8517, -0.8479, -0.8306],
#         [-0.4017,  0.5860, -0.2380,  0.8783],
#         [ 0.2729,  0.5715, -0.4626, -0.7107],
#         [ 0.0346,  0.3170,  0.0233, -0.3146]], requires_grad=True)
# nudges=[-0.01792044 -0.09616528 -0.01048782 -0.04663461 -0.0726676  -0.05945517
#  -0.07029421 -0.03182166  0.02682158 -0.08023767  0.02175894 -0.01666038
#   0.09230234  0.0266967  -0.00740293  0.08635012]
# weights after=Parameter containing:
# tensor([[-0.8458,  0.7556, -0.8584, -0.8772],
#         [-0.4743,  0.5265, -0.3083,  0.8465],
#         [ 0.2997,  0.4912, -0.4408, -0.7274],
#         [ 0.1269,  0.3437,  0.0159, -0.2283]], requires_grad=True)
#
# [INFO] signal=-0.8680667281150818
# weights before=Parameter containing:
# tensor([[-0.8458,  0.7556, -0.8584, -0.8772],
#         [-0.4743,  0.5265, -0.3083,  0.8465],
#         [ 0.2997,  0.4912, -0.4408, -0.7274],
#         [ 0.1269,  0.3437,  0.0159, -0.2283]], requires_grad=True)
# nudges=[-0.05665999 -0.01207031  0.0916621   0.01001861  0.05394819  0.07325267
#  -0.08742283  0.06830219 -0.09181857 -0.03943459 -0.07241201 -0.0137554
#   0.00910356  0.09481549  0.05715667  0.09162932]
# weights after=Parameter containing:
# tensor([[-0.9025,  0.7435, -0.7667, -0.8672],
#         [-0.4204,  0.5998, -0.3957,  0.9148],
#         [ 0.2079,  0.4518, -0.5132, -0.7411],
#         [ 0.1361,  0.4385,  0.0731, -0.1366]], requires_grad=True)
#
# [INFO] signal=-0.8277819156646729
# weights before=Parameter containing:
# tensor([[-0.9025,  0.7435, -0.7667, -0.8672],
#         [-0.4204,  0.5998, -0.3957,  0.9148],
#         [ 0.2079,  0.4518, -0.5132, -0.7411],
#         [ 0.1361,  0.4385,  0.0731, -0.1366]], requires_grad=True)
# nudges=[-0.07741347  0.05289482 -0.00970998 -0.07531752 -0.05022068 -0.00058599
#   0.09227332  0.08659258 -0.03959791 -0.08184073  0.01926602  0.0316385
#   0.06180748  0.0364713   0.0529428  -0.01218758]
# weights after=Parameter containing:
# tensor([[-0.9799,  0.7964, -0.7764, -0.9425],
#         [-0.4706,  0.5992, -0.3035,  1.0014],
#         [ 0.1683,  0.3700, -0.4940, -0.7095],
#         [ 0.1979,  0.4750,  0.1260, -0.1488]], requires_grad=True)
#
# [INFO] signal=-0.8741634488105774
# [INFO] Reset at 27
# weights before=Parameter containing:
# tensor([[-0.7951,  0.6267, -0.8307, -0.7619],
#         [-0.3047,  0.4708, -0.1719,  0.8580],
#         [-0.1162,  0.4736, -0.5573, -0.4005],
#         [ 0.2186,  0.2895, -0.1463, -0.2233]], requires_grad=True)
# nudges=[-0.00631683  0.04718562 -0.03542417  0.08998702 -0.0787854  -0.00774633
#   0.0103973   0.06004479 -0.03633929 -0.00831038 -0.04865135 -0.01131375
#  -0.03218987  0.09054703  0.06602449 -0.07755625]
# weights after=Parameter containing:
# tensor([[-0.8014,  0.6739, -0.8661, -0.6719],
#         [-0.3835,  0.4630, -0.1615,  0.9180],
#         [-0.1525,  0.4653, -0.6060, -0.4118],
#         [ 0.1864,  0.3801, -0.0802, -0.3009]], requires_grad=True)
#
# [INFO] signal=-0.9053452014923096
# weights before=Parameter containing:
# tensor([[-0.8014,  0.6739, -0.8661, -0.6719],
#         [-0.3835,  0.4630, -0.1615,  0.9180],
#         [-0.1525,  0.4653, -0.6060, -0.4118],
#         [ 0.1864,  0.3801, -0.0802, -0.3009]], requires_grad=True)
# nudges=[ 0.02811346  0.02457249  0.01907335 -0.02690706  0.05648386 -0.08625406
#   0.06865051  0.09907482 -0.07189474  0.09663539 -0.04029792 -0.08891578
#   0.01057913 -0.04919312 -0.04010282  0.07571503]
# weights after=Parameter containing:
# tensor([[-0.7733,  0.6984, -0.8471, -0.6988],
#         [-0.3270,  0.3768, -0.0928,  1.0171],
#         [-0.2244,  0.5619, -0.6463, -0.5007],
#         [ 0.1970,  0.3309, -0.1203, -0.2252]], requires_grad=True)
#
# [INFO] signal=-0.9341741800308228
# [INFO] Reset at 29
# weights before=Parameter containing:
# tensor([[-0.7951,  0.6267, -0.8307, -0.7619],
#         [-0.3047,  0.4708, -0.1719,  0.8580],
#         [-0.1162,  0.4736, -0.5573, -0.4005],
#         [ 0.2186,  0.2895, -0.1463, -0.2233]], requires_grad=True)
# nudges=[-0.02844664 -0.02844758 -0.05101007  0.02118909 -0.02104906  0.03584336
#  -0.08740434  0.04236213  0.03844418  0.0311792  -0.00200162  0.03379085
#   0.08955788  0.0395778  -0.08951383  0.01142982]
# weights after=Parameter containing:
# tensor([[-0.8236,  0.5982, -0.8817, -0.7407],
#         [-0.3257,  0.5066, -0.2593,  0.9003],
#         [-0.0778,  0.5048, -0.5593, -0.3667],
#         [ 0.3082,  0.3291, -0.2358, -0.2119]], requires_grad=True)
#
# [INFO] signal=-0.85955411195755
# weights before=Parameter containing:
# tensor([[-0.8236,  0.5982, -0.8817, -0.7407],
#         [-0.3257,  0.5066, -0.2593,  0.9003],
#         [-0.0778,  0.5048, -0.5593, -0.3667],
#         [ 0.3082,  0.3291, -0.2358, -0.2119]], requires_grad=True)
# nudges=[-0.04977919  0.00551061 -0.0412414  -0.05727405 -0.08603988 -0.03669516
#   0.05306043  0.02697576 -0.02700336 -0.09296726  0.05223615 -0.06941901
#   0.02060525  0.07121753 -0.01168213 -0.06516509]
# weights after=Parameter containing:
# tensor([[-0.8734,  0.6037, -0.9230, -0.7980],
#         [-0.4118,  0.4699, -0.2062,  0.9273],
#         [-0.1048,  0.4118, -0.5071, -0.4361],
#         [ 0.3288,  0.4003, -0.2475, -0.2771]], requires_grad=True)
#
# [INFO] signal=-0.8864595293998718
# weights before=Parameter containing:
# tensor([[-0.8734,  0.6037, -0.9230, -0.7980],
#         [-0.4118,  0.4699, -0.2062,  0.9273],
#         [-0.1048,  0.4118, -0.5071, -0.4361],
#         [ 0.3288,  0.4003, -0.2475, -0.2771]], requires_grad=True)
# nudges=[ 0.09182464  0.02051844  0.02048769  0.00420161 -0.01419106 -0.00483785
#  -0.04887505  0.0980778   0.01645265  0.04659767  0.00038719  0.02074091
#   0.00500654 -0.06410043 -0.03468519 -0.01856949]
# weights after=Parameter containing:
# tensor([[-0.7815,  0.6243, -0.9025, -0.7938],
#         [-0.4260,  0.4651, -0.2551,  1.0254],
#         [-0.0883,  0.4584, -0.5067, -0.4154],
#         [ 0.3338,  0.3362, -0.2822, -0.2957]], requires_grad=True)
#
# [INFO] signal=-0.8594745993614197
# [INFO] Reset at 32
# weights before=Parameter containing:
# tensor([[-0.7951,  0.6267, -0.8307, -0.7619],
#         [-0.3047,  0.4708, -0.1719,  0.8580],
#         [-0.1162,  0.4736, -0.5573, -0.4005],
#         [ 0.2186,  0.2895, -0.1463, -0.2233]], requires_grad=True)
# nudges=[-0.07145186 -0.06075971 -0.06839481 -0.02508729  0.09209732 -0.0790831
#   0.03789748 -0.04748015  0.02113514  0.04201471  0.05993377  0.03883395
#   0.09464108 -0.02623057  0.00906934  0.05373467]
# weights after=Parameter containing:
# tensor([[-0.8666,  0.5659, -0.8991, -0.7870],
#         [-0.2126,  0.3917, -0.1340,  0.8105],
#         [-0.0951,  0.5156, -0.4974, -0.3616],
#         [ 0.3132,  0.2633, -0.1372, -0.1696]], requires_grad=True)
#
# [INFO] signal=-0.922576904296875
# weights before=Parameter containing:
# tensor([[-0.8666,  0.5659, -0.8991, -0.7870],
#         [-0.2126,  0.3917, -0.1340,  0.8105],
#         [-0.0951,  0.5156, -0.4974, -0.3616],
#         [ 0.3132,  0.2633, -0.1372, -0.1696]], requires_grad=True)
# nudges=[ 0.04294043 -0.02246159 -0.04606475 -0.09883371  0.06043399  0.03556745
#  -0.05668143 -0.08852882  0.05413445  0.0551407   0.03672092  0.05741211
#  -0.03652708  0.09013455 -0.07850566 -0.01638249]
# weights after=Parameter containing:
# tensor([[-0.8236,  0.5435, -0.9452, -0.8858],
#         [-0.1521,  0.4273, -0.1907,  0.7220],
#         [-0.0409,  0.5707, -0.4607, -0.3042],
#         [ 0.2767,  0.3534, -0.2157, -0.1860]], requires_grad=True)
#
# [INFO] signal=-0.9007089734077454
# weights before=Parameter containing:
# tensor([[-0.8236,  0.5435, -0.9452, -0.8858],
#         [-0.1521,  0.4273, -0.1907,  0.7220],
#         [-0.0409,  0.5707, -0.4607, -0.3042],
#         [ 0.2767,  0.3534, -0.2157, -0.1860]], requires_grad=True)
# nudges=[-0.01299658  0.07424336 -0.03425407  0.04538681  0.03064353  0.05521891
#  -0.01471014 -0.03846784 -0.08605956  0.04532231  0.02027075  0.05159485
#  -0.0120205  -0.00726975  0.0464868  -0.0341559 ]
# weights after=Parameter containing:
# tensor([[-0.8366,  0.6177, -0.9794, -0.8404],
#         [-0.1215,  0.4825, -0.2054,  0.6835],
#         [-0.1270,  0.6161, -0.4404, -0.2526],
#         [ 0.2647,  0.3462, -0.1692, -0.2202]], requires_grad=True)
#
# [INFO] signal=-0.8975688219070435
# weights before=Parameter containing:
# tensor([[-0.8366,  0.6177, -0.9794, -0.8404],
#         [-0.1215,  0.4825, -0.2054,  0.6835],
#         [-0.1270,  0.6161, -0.4404, -0.2526],
#         [ 0.2647,  0.3462, -0.1692, -0.2202]], requires_grad=True)
# nudges=[-0.0161669   0.06027787 -0.00433294  0.04460899  0.01698929  0.02491705
#   0.08500385 -0.0174318  -0.07206613  0.01559161  0.01076323 -0.03281977
#   0.07529571 -0.09208531 -0.08765621  0.05238272]
# weights after=Parameter containing:
# tensor([[-0.8528,  0.6780, -0.9837, -0.7958],
#         [-0.1045,  0.5074, -0.1204,  0.6661],
#         [-0.1991,  0.6317, -0.4296, -0.2855],
#         [ 0.3400,  0.2541, -0.2569, -0.1678]], requires_grad=True)
#
# [INFO] signal=-0.9416937828063965
# weights before=Parameter containing:
# tensor([[-0.8528,  0.6780, -0.9837, -0.7958],
#         [-0.1045,  0.5074, -0.1204,  0.6661],
#         [-0.1991,  0.6317, -0.4296, -0.2855],
#         [ 0.3400,  0.2541, -0.2569, -0.1678]], requires_grad=True)
# nudges=[-0.06686701  0.08614536  0.06318752  0.05320079 -0.05890703  0.02235673
#  -0.01004904 -0.03994542 -0.04509976 -0.06951917 -0.06083404 -0.06135815
#  -0.03692516 -0.09501655  0.02954357  0.06036555]
# weights after=Parameter containing:
# tensor([[-0.9197,  0.7641, -0.9206, -0.7426],
#         [-0.1634,  0.5298, -0.1304,  0.6261],
#         [-0.2442,  0.5621, -0.4905, -0.3468],
#         [ 0.3031,  0.1591, -0.2273, -0.1074]], requires_grad=True)
#
# [INFO] signal=-0.9410626888275146
# weights before=Parameter containing:
# tensor([[-0.9197,  0.7641, -0.9206, -0.7426],
#         [-0.1634,  0.5298, -0.1304,  0.6261],
#         [-0.2442,  0.5621, -0.4905, -0.3468],
#         [ 0.3031,  0.1591, -0.2273, -0.1074]], requires_grad=True)
# nudges=[-0.07210442  0.03395154  0.08273613 -0.09271257  0.06086832 -0.0380205
#  -0.06087634  0.0980007  -0.09105503 -0.0220913  -0.08376987  0.0817956
#  -0.0931135   0.02259418 -0.04200767  0.06307035]
# weights after=Parameter containing:
# tensor([[-0.9918,  0.7981, -0.8378, -0.8353],
#         [-0.1025,  0.4917, -0.1913,  0.7241],
#         [-0.3352,  0.5400, -0.5742, -0.2650],
#         [ 0.2099,  0.1817, -0.2693, -0.0443]], requires_grad=True)
#
# [INFO] signal=-0.9082124829292297
# weights before=Parameter containing:
# tensor([[-0.9918,  0.7981, -0.8378, -0.8353],
#         [-0.1025,  0.4917, -0.1913,  0.7241],
#         [-0.3352,  0.5400, -0.5742, -0.2650],
#         [ 0.2099,  0.1817, -0.2693, -0.0443]], requires_grad=True)
# nudges=[-0.02103521  0.07884536 -0.07705699 -0.09576306  0.06895935 -0.01085258
#   0.01938721 -0.08817559  0.09492927 -0.00816958  0.01419626  0.0886125
#   0.07206053 -0.01154886  0.06281006  0.0955218 ]
# weights after=Parameter containing:
# tensor([[-1.0128,  0.8769, -0.9149, -0.9311],
#         [-0.0336,  0.4809, -0.1719,  0.6359],
#         [-0.2403,  0.5319, -0.5600, -0.1764],
#         [ 0.2820,  0.1701, -0.2065,  0.0512]], requires_grad=True)
#
# [INFO] signal=-0.9351862072944641
# [INFO] Reset at 39
# weights before=Parameter containing:
# tensor([[-0.7951,  0.6267, -0.8307, -0.7619],
#         [-0.3047,  0.4708, -0.1719,  0.8580],
#         [-0.1162,  0.4736, -0.5573, -0.4005],
#         [ 0.2186,  0.2895, -0.1463, -0.2233]], requires_grad=True)
# nudges=[-0.0409529   0.09223645 -0.00595403  0.02576738  0.0961029   0.07390522
#   0.09717491  0.03452023 -0.02127732  0.07002591 -0.00635514  0.0064548
#   0.04717334 -0.02486596 -0.03935838  0.04015075]
# weights after=Parameter containing:
# tensor([[-0.8361,  0.7189, -0.8367, -0.7361],
#         [-0.2086,  0.5447, -0.0747,  0.8925],
#         [-0.1375,  0.5436, -0.5637, -0.3940],
#         [ 0.2658,  0.2647, -0.1856, -0.1832]], requires_grad=True)
#
# [INFO] signal=-0.9456872940063477
# weights before=Parameter containing:
# tensor([[-0.8361,  0.7189, -0.8367, -0.7361],
#         [-0.2086,  0.5447, -0.0747,  0.8925],
#         [-0.1375,  0.5436, -0.5637, -0.3940],
#         [ 0.2658,  0.2647, -0.1856, -0.1832]], requires_grad=True)
# nudges=[ 0.07974564  0.07857487 -0.09682375  0.00246135  0.01912288 -0.08762487
#  -0.05173225 -0.01254112  0.0217737   0.05528594  0.06617289 -0.00811068
#  -0.02161545 -0.00464249 -0.08888652  0.08210734]
# weights after=Parameter containing:
# tensor([[-0.7563,  0.7975, -0.9335, -0.7337],
#         [-0.1894,  0.4571, -0.1264,  0.8799],
#         [-0.1157,  0.5989, -0.4975, -0.4021],
#         [ 0.2442,  0.2600, -0.2745, -0.1011]], requires_grad=True)
#
# [INFO] signal=-0.9232416152954102
# weights before=Parameter containing:
# tensor([[-0.7563,  0.7975, -0.9335, -0.7337],
#         [-0.1894,  0.4571, -0.1264,  0.8799],
#         [-0.1157,  0.5989, -0.4975, -0.4021],
#         [ 0.2442,  0.2600, -0.2745, -0.1011]], requires_grad=True)
# nudges=[-0.05862652 -0.03530876  0.03259792  0.06062231  0.00166766 -0.07491733
#   0.06531686  0.08938713 -0.08324288  0.00472498  0.06269249 -0.00895613
#  -0.08222888 -0.06409369  0.04679575 -0.07820772]
# weights after=Parameter containing:
# tensor([[-0.8150,  0.7622, -0.9009, -0.6730],
#         [-0.1878,  0.3821, -0.0611,  0.9693],
#         [-0.1990,  0.6036, -0.4348, -0.4111],
#         [ 0.1619,  0.1959, -0.2277, -0.1793]], requires_grad=True)
#
# [INFO] signal=-0.948363721370697
# weights before=Parameter containing:
# tensor([[-0.8150,  0.7622, -0.9009, -0.6730],
#         [-0.1878,  0.3821, -0.0611,  0.9693],
#         [-0.1990,  0.6036, -0.4348, -0.4111],
#         [ 0.1619,  0.1959, -0.2277, -0.1793]], requires_grad=True)
# nudges=[-0.00544645  0.01507882  0.05974355  0.04369975  0.08817514 -0.01498881
#  -0.06387393 -0.06776604  0.04004531 -0.09328932  0.04392951  0.00887927
#  -0.00755682 -0.09145114 -0.09953967 -0.00519589]
# weights after=Parameter containing:
# tensor([[-0.8204,  0.7773, -0.8411, -0.6293],
#         [-0.0996,  0.3671, -0.1250,  0.9016],
#         [-0.1589,  0.5103, -0.3909, -0.4022],
#         [ 0.1544,  0.1045, -0.3273, -0.1845]], requires_grad=True)
#
# [INFO] signal=-0.9205482602119446
# weights before=Parameter containing:
# tensor([[-0.8204,  0.7773, -0.8411, -0.6293],
#         [-0.0996,  0.3671, -0.1250,  0.9016],
#         [-0.1589,  0.5103, -0.3909, -0.4022],
#         [ 0.1544,  0.1045, -0.3273, -0.1845]], requires_grad=True)
# nudges=[ 0.00300964 -0.01467223 -0.03559158  0.03307923 -0.00979041 -0.00388955
#   0.01157346 -0.01797611  0.02313296  0.09385713  0.05968041 -0.08725861
#   0.02286409 -0.05321789 -0.01730282 -0.00383777]
# weights after=Parameter containing:
# tensor([[-0.8174,  0.7626, -0.8767, -0.5963],
#         [-0.1094,  0.3633, -0.1134,  0.8836],
#         [-0.1358,  0.6042, -0.3312, -0.4895],
#         [ 0.1772,  0.0513, -0.3446, -0.1883]], requires_grad=True)
#
# [INFO] signal=-0.9318007230758667
# weights before=Parameter containing:
# tensor([[-0.8174,  0.7626, -0.8767, -0.5963],
#         [-0.1094,  0.3633, -0.1134,  0.8836],
#         [-0.1358,  0.6042, -0.3312, -0.4895],
#         [ 0.1772,  0.0513, -0.3446, -0.1883]], requires_grad=True)
# nudges=[-0.07836214 -0.0869013   0.01468156  0.08812916 -0.00623828 -0.00121816
#  -0.02078708  0.08454835 -0.01249477 -0.0879254  -0.01987752 -0.07867402
#   0.09878453  0.02589219  0.09971138 -0.09365063]
# weights after=Parameter containing:
# tensor([[-0.8958,  0.6757, -0.8620, -0.5081],
#         [-0.1156,  0.3620, -0.1342,  0.9681],
#         [-0.1483,  0.5163, -0.3511, -0.5681],
#         [ 0.2760,  0.0772, -0.2449, -0.2820]], requires_grad=True)
#
# [INFO] signal=-0.9209400415420532
# weights before=Parameter containing:
# tensor([[-0.8958,  0.6757, -0.8620, -0.5081],
#         [-0.1156,  0.3620, -0.1342,  0.9681],
#         [-0.1483,  0.5163, -0.3511, -0.5681],
#         [ 0.2760,  0.0772, -0.2449, -0.2820]], requires_grad=True)
# nudges=[-0.02983426  0.04141369 -0.03836564 -0.04541339 -0.06267476 -0.09289362
#  -0.02298101  0.02507126  0.07730643 -0.03277226 -0.05603698 -0.05540052
#  -0.07396666  0.02259634  0.03588092  0.07130798]
# weights after=Parameter containing:
# tensor([[-0.9256,  0.7171, -0.9004, -0.5535],
#         [-0.1783,  0.2691, -0.1572,  0.9932],
#         [-0.0710,  0.4835, -0.4071, -0.6235],
#         [ 0.2020,  0.0997, -0.2090, -0.2107]], requires_grad=True)
#
# [INFO] signal=-0.9091882705688477
# weights before=Parameter containing:
# tensor([[-0.9256,  0.7171, -0.9004, -0.5535],
#         [-0.1783,  0.2691, -0.1572,  0.9932],
#         [-0.0710,  0.4835, -0.4071, -0.6235],
#         [ 0.2020,  0.0997, -0.2090, -0.2107]], requires_grad=True)
# nudges=[ 0.05151898  0.09542894 -0.00307018 -0.09162356 -0.05245789 -0.04921364
#   0.08150267  0.07130183 -0.03228676  0.09901416 -0.09225897 -0.08985425
#  -0.02027714  0.07391607  0.06006759 -0.03444449]
# weights after=Parameter containing:
# tensor([[-0.8741,  0.8125, -0.9035, -0.6452],
#         [-0.2308,  0.2199, -0.0757,  1.0645],
#         [-0.1033,  0.5825, -0.4994, -0.7134],
#         [ 0.1818,  0.1737, -0.1489, -0.2451]], requires_grad=True)
#
# [INFO] signal=-0.9480071067810059
# [INFO] Reset at 47
# weights before=Parameter containing:
# tensor([[-0.7951,  0.6267, -0.8307, -0.7619],
#         [-0.3047,  0.4708, -0.1719,  0.8580],
#         [-0.1162,  0.4736, -0.5573, -0.4005],
#         [ 0.2186,  0.2895, -0.1463, -0.2233]], requires_grad=True)
# nudges=[-0.06860217  0.02770445 -0.01383258 -0.03580611 -0.08383922  0.03063569
#   0.05480935 -0.0365252  -0.00791205  0.0096216   0.02088879 -0.09424629
#  -0.00629526  0.09854404 -0.00146895 -0.04189573]
# weights after=Parameter containing:
# tensor([[-0.8637,  0.6544, -0.8445, -0.7977],
#         [-0.3885,  0.5014, -0.1171,  0.8214],
#         [-0.1241,  0.4832, -0.5364, -0.4947],
#         [ 0.2123,  0.3881, -0.1477, -0.2652]], requires_grad=True)
#
# [INFO] signal=-0.9305514097213745
# weights before=Parameter containing:
# tensor([[-0.8637,  0.6544, -0.8445, -0.7977],
#         [-0.3885,  0.5014, -0.1171,  0.8214],
#         [-0.1241,  0.4832, -0.5364, -0.4947],
#         [ 0.2123,  0.3881, -0.1477, -0.2652]], requires_grad=True)
# nudges=[-0.08267654  0.08126771  0.0414841   0.09273099  0.00047071  0.05776087
#  -0.06446621 -0.01052025  0.02406387 -0.00209567  0.01746584 -0.03103758
#   0.07689055 -0.0526959   0.07220412 -0.04561204]
# weights after=Parameter containing:
# tensor([[-0.9464,  0.7356, -0.8030, -0.7050],
#         [-0.3880,  0.5592, -0.1815,  0.8109],
#         [-0.1001,  0.4811, -0.5190, -0.5258],
#         [ 0.2892,  0.3354, -0.0755, -0.3109]], requires_grad=True)
#
# [INFO] signal=-0.9073742032051086
# weights before=Parameter containing:
# tensor([[-0.9464,  0.7356, -0.8030, -0.7050],
#         [-0.3880,  0.5592, -0.1815,  0.8109],
#         [-0.1001,  0.4811, -0.5190, -0.5258],
#         [ 0.2892,  0.3354, -0.0755, -0.3109]], requires_grad=True)
# nudges=[-0.04138322 -0.0318222   0.0998294   0.03759063 -0.0732625   0.04787318
#  -0.01701131 -0.0103172   0.00019644  0.07636224 -0.00896037  0.09530919
#   0.04707711  0.07926821  0.07977482  0.04109497]
# weights after=Parameter containing:
# tensor([[-0.9878,  0.7038, -0.7032, -0.6674],
#         [-0.4613,  0.6070, -0.1986,  0.8006],
#         [-0.0999,  0.5575, -0.5279, -0.4305],
#         [ 0.3363,  0.4146,  0.0042, -0.2698]], requires_grad=True)
#
# [INFO] signal=-0.9112758040428162
# weights before=Parameter containing:
# tensor([[-0.9878,  0.7038, -0.7032, -0.6674],
#         [-0.4613,  0.6070, -0.1986,  0.8006],
#         [-0.0999,  0.5575, -0.5279, -0.4305],
#         [ 0.3363,  0.4146,  0.0042, -0.2698]], requires_grad=True)
# nudges=[ 0.00357802  0.03485738  0.02217933 -0.0433641   0.05930191 -0.01441756
#   0.09779214 -0.03588554  0.09955224 -0.05063171  0.02673691 -0.04893716
#  -0.05217505  0.049366   -0.09196063  0.03858138]
# weights after=Parameter containing:
# tensor([[-9.8421e-01,  7.3868e-01, -6.8104e-01, -7.1073e-01],
#         [-4.0200e-01,  5.9263e-01, -1.0076e-01,  7.6472e-01],
#         [-3.0710e-04,  5.0684e-01, -5.0119e-01, -4.7939e-01],
#         [ 2.8409e-01,  4.6401e-01, -8.7721e-02, -2.3118e-01]],
#        requires_grad=True)
#
# [INFO] signal=-0.9542667269706726
# weights before=Parameter containing:
# tensor([[-9.8421e-01,  7.3868e-01, -6.8104e-01, -7.1073e-01],
#         [-4.0200e-01,  5.9263e-01, -1.0076e-01,  7.6472e-01],
#         [-3.0710e-04,  5.0684e-01, -5.0119e-01, -4.7939e-01],
#         [ 2.8409e-01,  4.6401e-01, -8.7721e-02, -2.3118e-01]],
#        requires_grad=True)
# nudges=[ 0.06820502 -0.03063149 -0.09888006 -0.09912891 -0.0501384   0.07046049
#   0.07895017 -0.0245131  -0.02323162  0.01222037  0.00829027  0.02782889
#   0.04383197  0.06310786 -0.06519014  0.02927328]
# weights after=Parameter containing:
# tensor([[-0.9160,  0.7081, -0.7799, -0.8099],
#         [-0.4521,  0.6631, -0.0218,  0.7402],
#         [-0.0235,  0.5191, -0.4929, -0.4516],
#         [ 0.3279,  0.5271, -0.1529, -0.2019]], requires_grad=True)
#
# [INFO] signal=-0.9966407418251038
# weights before=Parameter containing:
# tensor([[-0.9160,  0.7081, -0.7799, -0.8099],
#         [-0.4521,  0.6631, -0.0218,  0.7402],
#         [-0.0235,  0.5191, -0.4929, -0.4516],
#         [ 0.3279,  0.5271, -0.1529, -0.2019]], requires_grad=True)
# nudges=[-0.09570814 -0.01012621  0.05885609 -0.0589069  -0.06194322 -0.07091147
#  -0.09390959 -0.08139572 -0.01609201  0.02858187  0.01567803  0.06955264
#  -0.02069221  0.00077353 -0.04232028 -0.02337801]
# weights after=Parameter containing:
# tensor([[-1.0117,  0.6979, -0.7211, -0.8688],
#         [-0.5141,  0.5922, -0.1157,  0.6588],
#         [-0.0396,  0.5476, -0.4772, -0.3820],
#         [ 0.3072,  0.5279, -0.1952, -0.2253]], requires_grad=True)
#
# [INFO] signal=-0.9583742022514343
# [INFO] Reset at 53
# weights before=Parameter containing:
# tensor([[-0.7951,  0.6267, -0.8307, -0.7619],
#         [-0.3047,  0.4708, -0.1719,  0.8580],
#         [-0.1162,  0.4736, -0.5573, -0.4005],
#         [ 0.2186,  0.2895, -0.1463, -0.2233]], requires_grad=True)
# nudges=[-0.00959443 -0.06070309 -0.00129993  0.00168516  0.05150302 -0.00552586
#  -0.01329348  0.085113   -0.02634197 -0.07845416 -0.04072993  0.07648154
#  -0.02451572 -0.06775342  0.07293781 -0.08739024]
# weights after=Parameter containing:
# tensor([[-0.8047,  0.5660, -0.8320, -0.7602],
#         [-0.2532,  0.4652, -0.1852,  0.9431],
#         [-0.1425,  0.3951, -0.5981, -0.3240],
#         [ 0.1941,  0.2218, -0.0733, -0.3107]], requires_grad=True)
#
# [INFO] signal=-0.89021235704422
# weights before=Parameter containing:
# tensor([[-0.8047,  0.5660, -0.8320, -0.7602],
#         [-0.2532,  0.4652, -0.1852,  0.9431],
#         [-0.1425,  0.3951, -0.5981, -0.3240],
#         [ 0.1941,  0.2218, -0.0733, -0.3107]], requires_grad=True)
# nudges=[ 0.02500313 -0.0652639   0.09449988 -0.04277592 -0.04104529 -0.09992936
#   0.03346654 -0.05349227  0.0865012   0.03487559 -0.04269188  0.09311696
#  -0.09687928  0.06917977  0.05570746 -0.00932477]
# weights after=Parameter containing:
# tensor([[-0.7797,  0.5007, -0.7375, -0.8030],
#         [-0.2942,  0.3653, -0.1517,  0.8896],
#         [-0.0560,  0.4300, -0.6407, -0.2309],
#         [ 0.0972,  0.2910, -0.0176, -0.3201]], requires_grad=True)
#
# [INFO] signal=-0.9117658138275146
# weights before=Parameter containing:
# tensor([[-0.7797,  0.5007, -0.7375, -0.8030],
#         [-0.2942,  0.3653, -0.1517,  0.8896],
#         [-0.0560,  0.4300, -0.6407, -0.2309],
#         [ 0.0972,  0.2910, -0.0176, -0.3201]], requires_grad=True)
# nudges=[-0.07227208 -0.08912145 -0.0323104  -0.09504366 -0.04703191  0.08229604
#  -0.08974626  0.06504592 -0.03367201  0.00659832 -0.04952759 -0.01801194
#  -0.09972745  0.04170447 -0.08679427 -0.0766866 ]
# weights after=Parameter containing:
# tensor([[-0.8520,  0.4116, -0.7698, -0.8980],
#         [-0.3412,  0.4476, -0.2415,  0.9546],
#         [-0.0897,  0.4366, -0.6903, -0.2489],
#         [-0.0025,  0.3327, -0.1044, -0.3967]], requires_grad=True)
#
# [INFO] signal=-0.8688209652900696
# weights before=Parameter containing:
# tensor([[-0.8520,  0.4116, -0.7698, -0.8980],
#         [-0.3412,  0.4476, -0.2415,  0.9546],
#         [-0.0897,  0.4366, -0.6903, -0.2489],
#         [-0.0025,  0.3327, -0.1044, -0.3967]], requires_grad=True)
# nudges=[-0.04880903 -0.05012146 -0.04241473  0.05935498 -0.0796182  -0.05550964
#   0.09615073 -0.08904312 -0.06105348  0.04327738 -0.00141916  0.01642825
#  -0.03227719 -0.04712826 -0.00451114  0.03467881]
# weights after=Parameter containing:
# tensor([[-0.9008,  0.3615, -0.8122, -0.8387],
#         [-0.4209,  0.3921, -0.1453,  0.8656],
#         [-0.1508,  0.4799, -0.6917, -0.2325],
#         [-0.0348,  0.2855, -0.1089, -0.3621]], requires_grad=True)
#
# [INFO] signal=-0.9207994937896729
# weights before=Parameter containing:
# tensor([[-0.9008,  0.3615, -0.8122, -0.8387],
#         [-0.4209,  0.3921, -0.1453,  0.8656],
#         [-0.1508,  0.4799, -0.6917, -0.2325],
#         [-0.0348,  0.2855, -0.1089, -0.3621]], requires_grad=True)
# nudges=[-0.00459116 -0.03128328 -0.06134379  0.06842523 -0.07215048  0.09807167
#  -0.03602299 -0.09387933 -0.07440487 -0.0367041  -0.09642607 -0.06627588
#   0.09296397 -0.09316338 -0.09247337 -0.02424448]
# weights after=Parameter containing:
# tensor([[-0.9054,  0.3302, -0.8736, -0.7702],
#         [-0.4930,  0.4902, -0.1813,  0.7717],
#         [-0.2252,  0.4432, -0.7881, -0.2987],
#         [ 0.0582,  0.1924, -0.2014, -0.3863]], requires_grad=True)
#
# [INFO] signal=-0.9134432077407837
# weights before=Parameter containing:
# tensor([[-0.9054,  0.3302, -0.8736, -0.7702],
#         [-0.4930,  0.4902, -0.1813,  0.7717],
#         [-0.2252,  0.4432, -0.7881, -0.2987],
#         [ 0.0582,  0.1924, -0.2014, -0.3863]], requires_grad=True)
# nudges=[ 0.05152836 -0.07601234  0.09114852 -0.07728908 -0.01135896 -0.08958083
#   0.09921125  0.07192724  0.04291914  0.0720753   0.01863476  0.05936506
#  -0.09033845 -0.0201837   0.04280274  0.04289297]
# weights after=Parameter containing:
# tensor([[-0.8539,  0.2542, -0.7824, -0.8475],
#         [-0.5044,  0.4006, -0.0821,  0.8436],
#         [-0.1823,  0.5153, -0.7695, -0.2394],
#         [-0.0322,  0.1722, -0.1586, -0.3434]], requires_grad=True)
#
# [INFO] signal=-0.9610981345176697
# weights before=Parameter containing:
# tensor([[-0.8539,  0.2542, -0.7824, -0.8475],
#         [-0.5044,  0.4006, -0.0821,  0.8436],
#         [-0.1823,  0.5153, -0.7695, -0.2394],
#         [-0.0322,  0.1722, -0.1586, -0.3434]], requires_grad=True)
# nudges=[ 0.09245988  0.05544632 -0.03211968  0.03599469  0.00578503 -0.08809542
#   0.0376981  -0.06657557 -0.09658217  0.03308325  0.01877727  0.06242748
#  -0.06101308  0.02334992  0.01936392 -0.03023204]
# weights after=Parameter containing:
# tensor([[-0.7614,  0.3096, -0.8145, -0.8115],
#         [-0.4986,  0.3125, -0.0444,  0.7771],
#         [-0.2788,  0.5483, -0.7507, -0.1769],
#         [-0.0932,  0.1955, -0.1392, -0.3737]], requires_grad=True)
#
# [INFO] signal=-0.9831987619400024
# weights before=Parameter containing:
# tensor([[-0.7614,  0.3096, -0.8145, -0.8115],
#         [-0.4986,  0.3125, -0.0444,  0.7771],
#         [-0.2788,  0.5483, -0.7507, -0.1769],
#         [-0.0932,  0.1955, -0.1392, -0.3737]], requires_grad=True)
# nudges=[ 0.0099981  -0.0977008   0.03013512 -0.05545676  0.02525409 -0.04197634
#   0.00321685  0.08978169 -0.01100018  0.06003896 -0.01559392 -0.03368845
#   0.06228109  0.07133164 -0.05739563 -0.0095528 ]
# weights after=Parameter containing:
# tensor([[-0.7514,  0.2119, -0.7844, -0.8670],
#         [-0.4733,  0.2705, -0.0412,  0.8668],
#         [-0.2898,  0.6084, -0.7663, -0.2106],
#         [-0.0309,  0.2669, -0.1966, -0.3832]], requires_grad=True)
#
# [INFO] signal=-0.9826905131340027
# weights before=Parameter containing:
# tensor([[-0.7514,  0.2119, -0.7844, -0.8670],
#         [-0.4733,  0.2705, -0.0412,  0.8668],
#         [-0.2898,  0.6084, -0.7663, -0.2106],
#         [-0.0309,  0.2669, -0.1966, -0.3832]], requires_grad=True)
# nudges=[ 0.02356384 -0.04626947 -0.06812081  0.00581242  0.00529064  0.07563593
#   0.06246807 -0.05136024  0.04167675 -0.07646915  0.03932413 -0.0287459
#  -0.02401062 -0.00638882 -0.08441281  0.04539091]
# weights after=Parameter containing:
# tensor([[-0.7278,  0.1656, -0.8525, -0.8612],
#         [-0.4680,  0.3462,  0.0213,  0.8155],
#         [-0.2482,  0.5319, -0.7270, -0.2394],
#         [-0.0549,  0.2605, -0.2810, -0.3378]], requires_grad=True)
#
# [INFO] signal=-1.0134437084197998
# weights before=Parameter containing:
# tensor([[-0.7278,  0.1656, -0.8525, -0.8612],
#         [-0.4680,  0.3462,  0.0213,  0.8155],
#         [-0.2482,  0.5319, -0.7270, -0.2394],
#         [-0.0549,  0.2605, -0.2810, -0.3378]], requires_grad=True)
# nudges=[ 0.06880083 -0.01206052 -0.04142217  0.08748127 -0.04175066  0.04387123
#   0.06875076 -0.03876149  0.05520161  0.05830006  0.02725413 -0.09954869
#   0.00804273  0.0501994  -0.01755213  0.01286833]
# weights after=Parameter containing:
# tensor([[-0.6590,  0.1536, -0.8939, -0.7737],
#         [-0.5098,  0.3900,  0.0900,  0.7767],
#         [-0.1930,  0.5902, -0.6997, -0.3389],
#         [-0.0469,  0.3107, -0.2986, -0.3249]], requires_grad=True)
#
# [INFO] signal=-1.0507423877716064
# weights before=Parameter containing:
# tensor([[-0.6590,  0.1536, -0.8939, -0.7737],
#         [-0.5098,  0.3900,  0.0900,  0.7767],
#         [-0.1930,  0.5902, -0.6997, -0.3389],
#         [-0.0469,  0.3107, -0.2986, -0.3249]], requires_grad=True)
# nudges=[ 0.05163591  0.0104362   0.05198569  0.0128059  -0.01451602 -0.04299743
#   0.00319578 -0.03911858  0.0037992   0.07095436  0.00858817 -0.07964163
#  -0.01929904  0.09074014  0.03006849  0.06144484]
# weights after=Parameter containing:
# tensor([[-0.6074,  0.1640, -0.8420, -0.7609],
#         [-0.5243,  0.3470,  0.0932,  0.7376],
#         [-0.1892,  0.6612, -0.6911, -0.4186],
#         [-0.0662,  0.4014, -0.2685, -0.2635]], requires_grad=True)
#
# [INFO] signal=-1.058286428451538
# weights before=Parameter containing:
# tensor([[-0.6074,  0.1640, -0.8420, -0.7609],
#         [-0.5243,  0.3470,  0.0932,  0.7376],
#         [-0.1892,  0.6612, -0.6911, -0.4186],
#         [-0.0662,  0.4014, -0.2685, -0.2635]], requires_grad=True)
# nudges=[-0.07737772 -0.08898714  0.07893481 -0.02584574  0.00919775  0.04624442
#  -0.08302397  0.08032378  0.02349852  0.05262645  0.07611134 -0.09172408
#   0.0973784  -0.00558968 -0.02342384  0.05494779]
# weights after=Parameter containing:
# tensor([[-0.6848,  0.0750, -0.7630, -0.7867],
#         [-0.5151,  0.3933,  0.0102,  0.8179],
#         [-0.1657,  0.7138, -0.6150, -0.5103],
#         [ 0.0312,  0.3958, -0.2920, -0.2086]], requires_grad=True)
#
# [INFO] signal=-1.0175769329071045
# weights before=Parameter containing:
# tensor([[-0.6848,  0.0750, -0.7630, -0.7867],
#         [-0.5151,  0.3933,  0.0102,  0.8179],
#         [-0.1657,  0.7138, -0.6150, -0.5103],
#         [ 0.0312,  0.3958, -0.2920, -0.2086]], requires_grad=True)
# nudges=[ 0.05960605  0.04328192  0.00572591 -0.09226929  0.08203023  0.09251096
#   0.07281921  0.03749438  0.03683073 -0.09387365  0.00205597 -0.04311256
#  -0.06853715  0.07659558 -0.03155689 -0.09792268]
# weights after=Parameter containing:
# tensor([[-0.6252,  0.1183, -0.7573, -0.8790],
#         [-0.4331,  0.4858,  0.0830,  0.8554],
#         [-0.1288,  0.6199, -0.6130, -0.5534],
#         [-0.0373,  0.4724, -0.3235, -0.3065]], requires_grad=True)
#
# [INFO] signal=-1.0466012954711914
# ...
#
# [INFO] signal=-0.9384602904319763
# weights before=Parameter containing:
# tensor([[-0.8164,  0.5297, -0.8278, -0.7476],
#         [-0.3908,  0.4815, -0.1169,  0.8214],
#         [-0.1950,  0.5781, -0.7700, -0.5839],
#         [ 0.0935,  0.3927, -0.0284, -0.2402]], requires_grad=True)
# nudges=[-0.07607482  0.03228589  0.0135532  -0.07928032  0.06777158  0.04739638
#   0.0236518   0.09724578  0.00501724 -0.05244064  0.08019326  0.07178033
#   0.09901454  0.0394825  -0.02621623 -0.04851308]
# weights after=Parameter containing:
# tensor([[-0.8925,  0.5619, -0.8142, -0.8269],
#         [-0.3230,  0.5289, -0.0933,  0.9187],
#         [-0.1900,  0.5257, -0.6898, -0.5121],
#         [ 0.1925,  0.4321, -0.0546, -0.2887]], requires_grad=True)
#
# [INFO] signal=-0.9413584470748901
# weights before=Parameter containing:
# tensor([[-0.8925,  0.5619, -0.8142, -0.8269],
#         [-0.3230,  0.5289, -0.0933,  0.9187],
#         [-0.1900,  0.5257, -0.6898, -0.5121],
#         [ 0.1925,  0.4321, -0.0546, -0.2887]], requires_grad=True)
# nudges=[ 0.01119547 -0.08546373  0.02302657  0.00616325 -0.01839228  0.00834914
#  -0.02609272 -0.0448769   0.07836422 -0.08926794  0.02712115  0.09616058
#   0.07246792  0.01030947  0.08965539  0.03737571]
# weights after=Parameter containing:
# tensor([[-0.8813,  0.4765, -0.7912, -0.8207],
#         [-0.3414,  0.5373, -0.1194,  0.8738],
#         [-0.1117,  0.4364, -0.6627, -0.4160],
#         [ 0.2650,  0.4425,  0.0350, -0.2513]], requires_grad=True)
#
# [INFO] signal=-0.9369142651557922
# weights before=Parameter containing:
# tensor([[-0.8813,  0.4765, -0.7912, -0.8207],
#         [-0.3414,  0.5373, -0.1194,  0.8738],
#         [-0.1117,  0.4364, -0.6627, -0.4160],
#         [ 0.2650,  0.4425,  0.0350, -0.2513]], requires_grad=True)
# nudges=[ 0.02297167  0.09150984 -0.05232299 -0.03269287 -0.06403998  0.08116216
#   0.03446832  0.01064372 -0.01491446  0.00418123 -0.01081263  0.08813398
#  -0.07634793 -0.05086857  0.08020639  0.02396013]
# weights after=Parameter containing:
# tensor([[-0.8583,  0.5680, -0.8435, -0.8534],
#         [-0.4054,  0.6185, -0.0849,  0.8844],
#         [-0.1266,  0.4406, -0.6735, -0.3278],
#         [ 0.1887,  0.3916,  0.1152, -0.2273]], requires_grad=True)
#
# [INFO] signal=-0.9582995176315308
# weights before=Parameter containing:
# tensor([[-0.8583,  0.5680, -0.8435, -0.8534],
#         [-0.4054,  0.6185, -0.0849,  0.8844],
#         [-0.1266,  0.4406, -0.6735, -0.3278],
#         [ 0.1887,  0.3916,  0.1152, -0.2273]], requires_grad=True)
# nudges=[ 0.00196682 -0.07712549  0.02274992 -0.09327915  0.0694982  -0.06613455
#   0.02176298  0.08912738 -0.08115886  0.02183644 -0.09665842 -0.02476292
#  -0.06118552  0.00644175 -0.05480269 -0.01842048]
# weights after=Parameter containing:
# tensor([[-0.8564,  0.4909, -0.8208, -0.9467],
#         [-0.3359,  0.5523, -0.0631,  0.9735],
#         [-0.2077,  0.4624, -0.7702, -0.3526],
#         [ 0.1275,  0.3980,  0.0604, -0.2458]], requires_grad=True)
#
# [INFO] signal=-0.9622287750244141
# weights before=Parameter containing:
# tensor([[-0.8564,  0.4909, -0.8208, -0.9467],
#         [-0.3359,  0.5523, -0.0631,  0.9735],
#         [-0.2077,  0.4624, -0.7702, -0.3526],
#         [ 0.1275,  0.3980,  0.0604, -0.2458]], requires_grad=True)
# nudges=[-0.09833542  0.08993668  0.03563397  0.0854091  -0.07190794  0.06493469
#  -0.09376138  0.0543445  -0.06424177  0.03442808 -0.0314009   0.01981874
#   0.01475313  0.06412407 -0.09577357  0.00095607]
# weights after=Parameter containing:
# tensor([[-0.9547,  0.5808, -0.7851, -0.8613],
#         [-0.4078,  0.6173, -0.1569,  1.0279],
#         [-0.2720,  0.4968, -0.8016, -0.3328],
#         [ 0.1422,  0.4622, -0.0353, -0.2448]], requires_grad=True)
#
# [INFO] signal=-0.9181462526321411
# [INFO] Reset at 91
# weights before=Parameter containing:
# tensor([[-0.7951,  0.6267, -0.8307, -0.7619],
#         [-0.3047,  0.4708, -0.1719,  0.8580],
#         [-0.1162,  0.4736, -0.5573, -0.4005],
#         [ 0.2186,  0.2895, -0.1463, -0.2233]], requires_grad=True)
# nudges=[-0.05329334  0.01725997 -0.09595384 -0.08578543 -0.03890131  0.09434379
#  -0.0573383  -0.03944585  0.06671081  0.04464852 -0.04053844 -0.00442009
#   0.06543041 -0.07257528  0.02694868  0.0256873 ]
# weights after=Parameter containing:
# tensor([[-0.8484,  0.6439, -0.9267, -0.8477],
#         [-0.3436,  0.5651, -0.2292,  0.8185],
#         [-0.0495,  0.5182, -0.5979, -0.4049],
#         [ 0.2840,  0.2170, -0.1193, -0.1977]], requires_grad=True)
#
# [INFO] signal=-0.8821212649345398
# weights before=Parameter containing:
# tensor([[-0.8484,  0.6439, -0.9267, -0.8477],
#         [-0.3436,  0.5651, -0.2292,  0.8185],
#         [-0.0495,  0.5182, -0.5979, -0.4049],
#         [ 0.2840,  0.2170, -0.1193, -0.1977]], requires_grad=True)
# nudges=[-0.04178936  0.02510548  0.05556736 -0.04018502  0.0220684   0.00986107
#  -0.04802323  0.04089565 -0.04813514  0.01441817 -0.08510164  0.00244416
#  -0.02662668 -0.07895869  0.00797118 -0.04816935]
# weights after=Parameter containing:
# tensor([[-0.8902,  0.6690, -0.8711, -0.8879],
#         [-0.3215,  0.5750, -0.2772,  0.8594],
#         [-0.0976,  0.5326, -0.6830, -0.4025],
#         [ 0.2574,  0.1380, -0.1114, -0.2458]], requires_grad=True)
#
# [INFO] signal=-0.8586422204971313
# weights before=Parameter containing:
# tensor([[-0.8902,  0.6690, -0.8711, -0.8879],
#         [-0.3215,  0.5750, -0.2772,  0.8594],
#         [-0.0976,  0.5326, -0.6830, -0.4025],
#         [ 0.2574,  0.1380, -0.1114, -0.2458]], requires_grad=True)
# nudges=[ 0.06229191  0.01743482  0.09323447 -0.06749661  0.03095297  0.09926983
#  -0.06654915  0.07239258 -0.0894102   0.07812589  0.08590689  0.01167227
#  -0.03215388  0.05450391  0.06007796  0.04889635]
# weights after=Parameter containing:
# tensor([[-0.8279,  0.6865, -0.7779, -0.9554],
#         [-0.2906,  0.6742, -0.3438,  0.9318],
#         [-0.1870,  0.6108, -0.5971, -0.3908],
#         [ 0.2252,  0.1925, -0.0513, -0.1969]], requires_grad=True)
#
# [INFO] signal=-0.8305275440216064
# weights before=Parameter containing:
# tensor([[-0.8279,  0.6865, -0.7779, -0.9554],
#         [-0.2906,  0.6742, -0.3438,  0.9318],
#         [-0.1870,  0.6108, -0.5971, -0.3908],
#         [ 0.2252,  0.1925, -0.0513, -0.1969]], requires_grad=True)
# nudges=[-0.07902635 -0.01562644  0.09444832  0.00449995  0.05371547  0.02752329
#  -0.02092347 -0.02630872  0.0393559   0.04378133  0.03602654  0.04187425
#   0.00637492  0.07470684  0.08150973  0.08831296]
# weights after=Parameter containing:
# tensor([[-0.9069,  0.6708, -0.6834, -0.9509],
#         [-0.2368,  0.7018, -0.3647,  0.9055],
#         [-0.1477,  0.6546, -0.5610, -0.3489],
#         [ 0.2316,  0.2672,  0.0302, -0.1086]], requires_grad=True)
#
# [INFO] signal=-0.8299490809440613
# weights before=Parameter containing:
# tensor([[-0.9069,  0.6708, -0.6834, -0.9509],
#         [-0.2368,  0.7018, -0.3647,  0.9055],
#         [-0.1477,  0.6546, -0.5610, -0.3489],
#         [ 0.2316,  0.2672,  0.0302, -0.1086]], requires_grad=True)
# nudges=[ 0.09588841 -0.05057326  0.03319681 -0.06843315 -0.07809895  0.0261384
#  -0.06361692 -0.08224396 -0.04117432  0.08537068 -0.08070377  0.02763779
#  -0.09158876  0.00384051 -0.09467042  0.01787289]
# weights after=Parameter containing:
# tensor([[-0.8111,  0.6203, -0.6502, -1.0193],
#         [-0.3149,  0.7279, -0.4283,  0.8233],
#         [-0.1889,  0.7399, -0.6417, -0.3213],
#         [ 0.1400,  0.2710, -0.0644, -0.0907]], requires_grad=True)
#
# [INFO] signal=-0.8084303140640259
# [INFO] Reset at 96
# weights before=Parameter containing:
# tensor([[-0.7951,  0.6267, -0.8307, -0.7619],
#         [-0.3047,  0.4708, -0.1719,  0.8580],
#         [-0.1162,  0.4736, -0.5573, -0.4005],
#         [ 0.2186,  0.2895, -0.1463, -0.2233]], requires_grad=True)
# nudges=[ 0.08262645 -0.00309753  0.00427519 -0.02069902  0.06082044  0.01708646
#   0.05309325 -0.03069945  0.07910892  0.06178894 -0.05684572  0.07510575
#   0.02457069  0.0863907  -0.0722493  -0.01125982]
# weights after=Parameter containing:
# tensor([[-0.7125,  0.6236, -0.8264, -0.7826],
#         [-0.2439,  0.4879, -0.1188,  0.8273],
#         [-0.0371,  0.5354, -0.6142, -0.3254],
#         [ 0.2432,  0.3759, -0.2185, -0.2346]], requires_grad=True)
#
# [INFO] signal=-0.9258615374565125
# weights before=Parameter containing:
# tensor([[-0.7125,  0.6236, -0.8264, -0.7826],
#         [-0.2439,  0.4879, -0.1188,  0.8273],
#         [-0.0371,  0.5354, -0.6142, -0.3254],
#         [ 0.2432,  0.3759, -0.2185, -0.2346]], requires_grad=True)
# nudges=[ 0.08303212  0.0250733  -0.06435265  0.02801881 -0.0549948   0.03213447
#  -0.03989501  0.07951646 -0.02703639  0.07471441  0.00836103  0.02362375
#  -0.01143897  0.04944839 -0.04652862  0.02983647]
# weights after=Parameter containing:
# tensor([[-0.6295,  0.6487, -0.8908, -0.7546],
#         [-0.2988,  0.5200, -0.1587,  0.9068],
#         [-0.0641,  0.6101, -0.6058, -0.3018],
#         [ 0.2317,  0.4254, -0.2650, -0.2048]], requires_grad=True)
#
# [INFO] signal=-0.9078651666641235
# weights before=Parameter containing:
# tensor([[-0.6295,  0.6487, -0.8908, -0.7546],
#         [-0.2988,  0.5200, -0.1587,  0.9068],
#         [-0.0641,  0.6101, -0.6058, -0.3018],
#         [ 0.2317,  0.4254, -0.2650, -0.2048]], requires_grad=True)
# nudges=[-0.07595187 -0.00275908 -0.00631662 -0.02492665 -0.02280023  0.08430111
#  -0.05916933  0.07217177 -0.00162323 -0.00710158 -0.02839796  0.07687216
#   0.03761592 -0.09610224 -0.04728711 -0.08242618]
# weights after=Parameter containing:
# tensor([[-0.7054,  0.6459, -0.8971, -0.7795],
#         [-0.3216,  0.6043, -0.2179,  0.9790],
#         [-0.0658,  0.6030, -0.6342, -0.2249],
#         [ 0.2693,  0.3293, -0.3123, -0.2872]], requires_grad=True)
#
# [INFO] signal=-0.8788609504699707
# weights before=Parameter containing:
# tensor([[-0.7054,  0.6459, -0.8971, -0.7795],
#         [-0.3216,  0.6043, -0.2179,  0.9790],
#         [-0.0658,  0.6030, -0.6342, -0.2249],
#         [ 0.2693,  0.3293, -0.3123, -0.2872]], requires_grad=True)
# nudges=[-0.01307675 -0.00142984  0.02855011  0.07086102 -0.01970372 -0.05297481
#   0.07594135  0.0811324  -0.07839287  0.07349046 -0.04968058 -0.07377498
#  -0.05254638 -0.01618563 -0.04132698 -0.0119087 ]
# weights after=Parameter containing:
# tensor([[-0.7185,  0.6445, -0.8685, -0.7086],
#         [-0.3413,  0.5513, -0.1419,  1.0601],
#         [-0.1442,  0.6765, -0.6839, -0.2987],
#         [ 0.2168,  0.3131, -0.3537, -0.2991]], requires_grad=True)
#
# [INFO] signal=-0.9106041193008423
# [INFO] Reset at 100
# weights before=Parameter containing:
# tensor([[-0.7951,  0.6267, -0.8307, -0.7619],
#         [-0.3047,  0.4708, -0.1719,  0.8580],
#         [-0.1162,  0.4736, -0.5573, -0.4005],
#         [ 0.2186,  0.2895, -0.1463, -0.2233]], requires_grad=True)
# nudges=[ 0.00018016 -0.04782848  0.08980548 -0.02304053  0.07860561 -0.07968313
#  -0.07364663  0.07090404 -0.04599873  0.08485072  0.00574768  0.09781604
#  -0.04062206  0.02535333  0.08003984  0.08487514]
# weights after=Parameter containing:
# tensor([[-0.7949,  0.5788, -0.7409, -0.7849],
#         [-0.2261,  0.3911, -0.2455,  0.9289],
#         [-0.1622,  0.5584, -0.5516, -0.3027],
#         [ 0.1780,  0.3149, -0.0662, -0.1385]], requires_grad=True)
#
# [INFO] signal=-0.8653189539909363
# weights before=Parameter containing:
# tensor([[-0.7949,  0.5788, -0.7409, -0.7849],
#         [-0.2261,  0.3911, -0.2455,  0.9289],
#         [-0.1622,  0.5584, -0.5516, -0.3027],
#         [ 0.1780,  0.3149, -0.0662, -0.1385]], requires_grad=True)
# nudges=[-0.08620591 -0.08886995 -0.04871974  0.09758358  0.02121983  0.0864423
#   0.03784151 -0.08656026  0.0655335   0.02399285 -0.08542248  0.09283473
#  -0.09682472 -0.09752783 -0.08034091 -0.09384174]
# weights after=Parameter containing:
# tensor([[-0.8812,  0.4900, -0.7896, -0.6873],
#         [-0.2048,  0.4775, -0.2077,  0.8423],
#         [-0.0967,  0.5824, -0.6370, -0.2098],
#         [ 0.0811,  0.2174, -0.1466, -0.2323]], requires_grad=True)
#
# [INFO] signal=-0.885258138179779
# weights before=Parameter containing:
# tensor([[-0.8812,  0.4900, -0.7896, -0.6873],
#         [-0.2048,  0.4775, -0.2077,  0.8423],
#         [-0.0967,  0.5824, -0.6370, -0.2098],
#         [ 0.0811,  0.2174, -0.1466, -0.2323]], requires_grad=True)
# nudges=[ 0.07301392 -0.08008467 -0.02927755 -0.01351353 -0.07350381  0.02466192
#   0.09370399 -0.08301441 -0.03972065 -0.00179575 -0.02961454  0.06255458
#  -0.07122912 -0.01437773 -0.00326688  0.04983335]
# weights after=Parameter containing:
# tensor([[-0.8081,  0.4099, -0.8189, -0.7009],
#         [-0.2783,  0.5022, -0.1140,  0.7593],
#         [-0.1364,  0.5806, -0.6666, -0.1473],
#         [ 0.0099,  0.2030, -0.1498, -0.1825]], requires_grad=True)
#
# [INFO] signal=-0.9395268559455872
# weights before=Parameter containing:
# tensor([[-0.8081,  0.4099, -0.8189, -0.7009],
#         [-0.2783,  0.5022, -0.1140,  0.7593],
#         [-0.1364,  0.5806, -0.6666, -0.1473],
#         [ 0.0099,  0.2030, -0.1498, -0.1825]], requires_grad=True)
# nudges=[ 0.02498783 -0.06352238 -0.08092351  0.06064723  0.09126205 -0.07697617
#   0.06083369 -0.09534556  0.01751266  0.0156406  -0.09288642 -0.059118
#   0.08572651 -0.05972188 -0.08224829 -0.07469431]
# weights after=Parameter containing:
# tensor([[-0.7832,  0.3464, -0.8998, -0.6402],
#         [-0.1871,  0.4252, -0.0532,  0.6640],
#         [-0.1189,  0.5963, -0.7595, -0.2064],
#         [ 0.0956,  0.1433, -0.2321, -0.2572]], requires_grad=True)
#
# [INFO] signal=-0.974051296710968
# weights before=Parameter containing:
# tensor([[-0.7832,  0.3464, -0.8998, -0.6402],
#         [-0.1871,  0.4252, -0.0532,  0.6640],
#         [-0.1189,  0.5963, -0.7595, -0.2064],
#         [ 0.0956,  0.1433, -0.2321, -0.2572]], requires_grad=True)
# nudges=[-0.07683365 -0.05342316  0.02953527 -0.092541    0.02312437 -0.09256493
#   0.04259164 -0.00053267 -0.07804744 -0.04924291  0.05829952 -0.06057232
#  -0.07234894  0.00428836  0.04975028 -0.03463184]
# weights after=Parameter containing:
# tensor([[-0.8600,  0.2929, -0.8703, -0.7327],
#         [-0.1640,  0.3327, -0.0106,  0.6634],
#         [-0.1969,  0.5470, -0.7012, -0.2670],
#         [ 0.0233,  0.1475, -0.1823, -0.2918]], requires_grad=True)
#
# [INFO] signal=-0.993229866027832
# weights before=Parameter containing:
# tensor([[-0.8600,  0.2929, -0.8703, -0.7327],
#         [-0.1640,  0.3327, -0.0106,  0.6634],
#         [-0.1969,  0.5470, -0.7012, -0.2670],
#         [ 0.0233,  0.1475, -0.1823, -0.2918]], requires_grad=True)
# nudges=[-0.01766301  0.01287411 -0.02530102  0.09548835  0.09210514 -0.0371171
#   0.09062078 -0.03798766 -0.03546544 -0.06876646 -0.02846295  0.07305826
#   0.07933746  0.02898232  0.01453433 -0.07634614]
# weights after=Parameter containing:
# tensor([[-0.8776,  0.3058, -0.8956, -0.6373],
#         [-0.0719,  0.2955,  0.0801,  0.6254],
#         [-0.2324,  0.4783, -0.7297, -0.1939],
#         [ 0.1026,  0.1765, -0.1678, -0.3682]], requires_grad=True)
#
# [INFO] signal=-1.043714165687561
# weights before=Parameter containing:
# tensor([[-0.8776,  0.3058, -0.8956, -0.6373],
#         [-0.0719,  0.2955,  0.0801,  0.6254],
#         [-0.2324,  0.4783, -0.7297, -0.1939],
#         [ 0.1026,  0.1765, -0.1678, -0.3682]], requires_grad=True)
# nudges=[-0.06795375  0.03811152 -0.08182888  0.00267154 -0.01546389  0.03495393
#   0.03485044  0.03099561  0.06155243 -0.03939409 -0.03025024 -0.09504744
#  -0.06566331  0.02500279  0.06949466  0.0628617 ]
# weights after=Parameter containing:
# tensor([[-0.9456,  0.3439, -0.9774, -0.6346],
#         [-0.0873,  0.3305,  0.1149,  0.6564],
#         [-0.1708,  0.4389, -0.7599, -0.2890],
#         [ 0.0370,  0.2015, -0.0983, -0.3053]], requires_grad=True)
#
# [INFO] signal=-1.05905020236969
# weights before=Parameter containing:
# tensor([[-0.9456,  0.3439, -0.9774, -0.6346],
#         [-0.0873,  0.3305,  0.1149,  0.6564],
#         [-0.1708,  0.4389, -0.7599, -0.2890],
#         [ 0.0370,  0.2015, -0.0983, -0.3053]], requires_grad=True)
# nudges=[ 0.02963752  0.01837562 -0.05070651 -0.06523566 -0.01140691  0.02487987
#  -0.06538942  0.06962345 -0.05328872 -0.0115995  -0.03183825 -0.06037152
#  -0.08934529  0.0193182   0.03994236  0.07616939]
# weights after=Parameter containing:
# tensor([[-0.9160,  0.3623, -1.0281, -0.6998],
#         [-0.0987,  0.3554,  0.0495,  0.7261],
#         [-0.2241,  0.4273, -0.7918, -0.3493],
#         [-0.0524,  0.2208, -0.0584, -0.2291]], requires_grad=True)
#
# [INFO] signal=-1.0241519212722778
# [INFO] Reset at 108

# %% [markdown]
# ### meta analysis

# %% [markdown]
# #### speed of training test

# %%
# get loss for meta trained network per step
reml = REML(layer_pool=pool, tasks=tasks)
reml.model.load(path)
meta_lossperstep_bytask = reml.evaluate_loss_curves()

# get loss for vanilla network per step
vanilla_lossperstep_bytask = {}
for task, x, y in zip(tasks, tasks_data, tasks_targets):
    model = RegressionModel()
    criterion = torch.nn.MSELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
    model.train()
    vanilla_lossperstep_bytask[task] = []
    for epoch in range(100):
        optimizer.zero_grad() 
        outputs = model(x.view(-1, 1))
        loss = criterion(outputs, y.view(-1,1))
        loss.backward()
        optimizer.step()
        vanilla_lossperstep_bytask[task].append(loss)

# %%
for i, (x, y) in enumerate(zip(tasks_data, tasks_targets)):
    task = tasks[i]
    vanilla_label = f'Vanilla network: Task {i+1}' 
    meta_label = f'Meta-trained network: Task {i+1}' 
    meta_loss_vals = [val.detach().numpy() for val in meta_lossperstep_bytask[task]]
    vanilla_loss_vals = [val.detach().numpy() for val in vanilla_lossperstep_bytask[task]]
    plt.plot(range(100), vanilla_loss_vals, label=vanilla_label)
    plt.plot(range(100), meta_loss_vals, label=meta_label)
    plt.xlabel('Timestep')
    plt.ylabel('MSE loss')
    plt.legend()
    plt.show()

# %% [markdown]
# #### few shot learning tests

# %% [markdown]
# k=5

# %%
# unseen task
# choose 5 and 10 datapoints on it, K = 5, K = 10
k = 5
k_pairs = torch.tensor(random.sample(list(zip(eval_task.data, eval_task.targets)), k))
print(len(k_pairs))
print(k_pairs)

# network still recieves the same 100 x values {-5, ..., 5}
# the difference is that a target value is only provided for 5 or 10 of these 100 values
# start by generating the 'pre-update' curve 
# next pass k datapoints and do 1 gradient update step to get the curve
# next do 9 more gradient update steps (total 10) to get next curve
# plot 'pre-update', '1 grad step', '10 grad steps' curves together with the 'k_pairs' data points

# %%
# env with eval task
reml = REML(layer_pool=pool, tasks=tasks)
reml.model.load(path)
env = reml.make_env(eval_task, pool)
reml.model.set_env(env)
reml.env = env
reml.task = eval_task

# ground truth
plt.plot(eval_task.data, eval_task.targets, linestyle='--', label='ground truth')

# pre-update
reml.generate_sine_curve(env=env, args={'linestyle' : '--', 'label': 'pre-update'})

# k points 
plt.scatter(k_pairs[:, 0], k_pairs[:, 1], marker='^', color='b', label='k points')

# train for 1 grad step
reml.env.batch_size = k
obs, _ = reml.env.reset()
for _ in range(1):
    action, _ = reml.model.predict(obs)
    obs, _, _, _, _ = reml.env.step(action)
reml.generate_sine_curve(env=env, args={'label' :'1 grad step'})
    
# train for 10 grad steps
obs, _ = reml.env.reset()
for _ in range(10):
    action, _ = reml.model.predict(obs)
    obs, _, _, _, _ = reml.env.step(action)
reml.generate_sine_curve(env=env, args={'label' : '10 grad steps'})
plt.title('REML, k=5')

# %% [markdown]
# k=10

# %%
k = 10
k_pairs = torch.tensor(random.sample(list(zip(eval_task.data, eval_task.targets)), k))
print(len(k_pairs))
print(k_pairs)

# %%
reml = REML(layer_pool=pool, tasks=tasks)
reml.model.load(path)
env = reml.make_env(eval_task)
reml.model.set_env(env)
reml.env = env
reml.task = eval_task

# ground truth
plt.plot(eval_task.data, eval_task.targets, linestyle='--', label='ground truth')

# pre-update
reml.generate_sine_curve(env=env, args={'linestyle' : '--', 'label': 'pre-update'})

# k points 
plt.scatter(k_pairs[:, 0], k_pairs[:, 1], marker='^', color='b', label='k points')

# train for 1 grad step
reml.env.batch_size = k
obs, _ = reml.env.reset()
for _ in range(1):
    action, _ = reml.model.predict(obs)
    obs, _, _, _, _ = reml.env.step(action)
reml.generate_sine_curve(env=env, args={'label' :'1 grad step'})
    
# train for 10 grad steps
obs, _ = reml.env.reset()
for _ in range(10):
    action, _ = reml.model.predict(obs)
    obs, _, _, _, _ = reml.env.step(action)
reml.generate_sine_curve(env=env, args={'label' : '10 grad steps'})
plt.title('REML, k=10')

# %% [markdown]
# ## episodic learning

# %%
config['episodic'] = True
config

# %%
tasks = [InnerNetworkTask(data=tasks_data[i], targets=tasks_targets[i], info=tasks_info[i]) for i in range(config['n_tasks'])]
eval_task = random.choice(list(tasks))
training_tasks = list(set(tasks) - {eval_task})
pool = LayerPool(layers=layers) if config['pretrain'] else LayerPool(layers=None)
reml = REML(layer_pool=pool, tasks=training_tasks)

# %%
reml.train()
path = f"meta_episodic_{config['sb3_model']}_{datetime.datetime.now().strftime('%H-%M')}"
reml.model.save(path)

# %%
# get loss for meta trained network per step
reml = REML(layer_pool=pool, tasks=tasks)
reml.model.load(path)
meta_lossperstep_bytask = reml.evaluate_loss_curves()

# get loss for vanilla network per step
vanilla_lossperstep_bytask = {}
for task, x, y in zip(tasks, tasks_data, tasks_targets):
    model = RegressionModel()
    criterion = torch.nn.MSELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=config['learning_rate'])
    model.train()
    vanilla_lossperstep_bytask[task] = []
    for epoch in range(100):
        optimizer.zero_grad() 
        outputs = model(x.view(-1, 1))
        loss = criterion(outputs, y.view(-1,1))
        loss.backward()
        optimizer.step()
        vanilla_lossperstep_bytask[task].append(loss)

# %%
for i, (x, y) in enumerate(zip(tasks_data, tasks_targets)):
    task = tasks[i]
    vanilla_label = f'Vanilla network: Task {i+1}' 
    meta_label = f'Meta-trained network: Task {i+1}' 
    meta_loss_vals = [val.detach().numpy() for val in meta_lossperstep_bytask[task]]
    vanilla_loss_vals = [val.detach().numpy() for val in vanilla_lossperstep_bytask[task]]
    plt.plot(range(100), vanilla_loss_vals, label=vanilla_label)
    plt.plot(range(100), meta_loss_vals, label=meta_label)
    plt.xlabel('Timestep')
    plt.ylabel('MSE loss')
    plt.legend()
    plt.show()

# %% [markdown]
# #### k=5

# %%
k = 5
k_pairs = torch.tensor(random.sample(list(zip(eval_task.data, eval_task.targets)), k))
print(len(k_pairs))
print(k_pairs)

# %%
# env with eval task
reml = REML(layer_pool=pool, tasks=tasks)
reml.model.load(path)
env = reml.make_env(eval_task, pool)
reml.model.set_env(env)
reml.env = env
reml.task = eval_task

# ground truth
plt.plot(eval_task.data, eval_task.targets, linestyle='--', label='ground truth')

# pre-update
reml.generate_sine_curve(env=env, args={'linestyle' : '--', 'label': 'pre-update'})

# k points 
plt.scatter(k_pairs[:, 0], k_pairs[:, 1], marker='^', color='b', label='k points')

# train for 1 grad step
reml.env.batch_size = k
obs, _ = reml.env.reset()
for _ in range(1):
    action, _ = reml.model.predict(obs)
    obs, _, _, _, _ = reml.env.step(action)
reml.generate_sine_curve(env=env, args={'label' :'1 grad step'})
    
# train for 10 grad steps
obs, _ = reml.env.reset()
for _ in range(10):
    action, _ = reml.model.predict(obs)
    obs, _, _, _, _ = reml.env.step(action)
reml.generate_sine_curve(env=env, args={'label' : '10 grad steps'})
plt.title('REML, k=5')
