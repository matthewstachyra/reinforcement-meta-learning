# %%
import math
import random
import datetime
from collections import defaultdict
from enum import Enum
import numpy as np 
import torch
import torch.nn.functional as F
from torch.utils.data import Dataset
from torch.utils.data import DataLoader
from torch.nn import Module
import gymnasium as gym
from gym import Env
from sklearn.model_selection import train_test_split
from gym.spaces.box import Box
from gym.spaces.discrete import Discrete
from gym.utils.env_checker import check_env
from typing import (
    Type,
    OrderedDict,
    List,
    Tuple,
    Callable,
)
import matplotlib.pyplot as plt
import stable_baselines3
from sb3_contrib import RecurrentPPO
from stable_baselines3 import PPO
from stable_baselines3.common.env_checker import check_env
from torch.utils.tensorboard import SummaryWriter

# %% [markdown]
# - See if there is transfer from learning regression models from a couple different sine curves to yet a different sine curve.
# - We know there is transfer is (1) it takes less to train and (2) if the model chooses to reuse layers rather than create new ones.
# - We first train regression models without the meta-learner (because the 'meta' ability cannot do anything without pre-trained weights).
# - The meta-learner will then output actions to build a model for unseen data.
# - Actions will be continuous, a vector of probabilities corresponding to which layer to add from the layer pool. One of these probabilities corresponds to adding no layer and just training the architecture as it is.

# %% [markdown]
# ## config

# %%
config = {
    'SEED' : 41,
    'DEVICE' : 'cuda',
    'EPOCHS' : 2,
    'TIMESTEPS' : 20000,
    'N_X' : 100,
    'N_TASKS' : 5,
    'IN_FEATURES' : 1,
    'OUT_FEATURES' : 1,
    'POOL_N_LAYERS' : 30,
    'N_NODES_PER_LAYER' : 32,
    'POOL_LAYER_TYPE' : torch.nn.Linear,
    'ACTION_SPACE_SHAPE' : (3,),
    'EPSILON' : 0.1,
    'BATCH_SIZE' : 1,
    'LEARNING_RATE' : 0.01,
    'ACTION_CACHE_SIZE' : 5,
    'NUM_WORKERS' : 0,
    'LOSS_FN' : torch.nn.MSELoss(),
    'SB3_MODEL' : RecurrentPPO,
    'SB3_POLICY' : 'MlpLstmPolicy',
    }
config
# Out:
# {'SEED': 41,
#  'DEVICE': 'cuda',
#  'EPOCHS': 2,
#  'TIMESTEPS': 20000,
#  'N_X': 100,
#  'N_TASKS': 5,
#  'IN_FEATURES': 1,
#  'OUT_FEATURES': 1,
#  'POOL_N_LAYERS': 30,
#  'N_NODES_PER_LAYER': 32,
#  'POOL_LAYER_TYPE': torch.nn.modules.linear.Linear,
#  'ACTION_SPACE_SHAPE': (3,),
#  'EPSILON': 0.1,
#  'BATCH_SIZE': 1,
#  'LEARNING_RATE': 0.01,
#  'ACTION_CACHE_SIZE': 5,
#  'NUM_WORKERS': 0,
#  'LOSS_FN': MSELoss(),
#  'SB3_MODEL': sb3_contrib.ppo_recurrent.ppo_recurrent.RecurrentPPO,
#  'SB3_POLICY': 'MlpLstmPolicy'}

# %%
torch.cuda.is_available()
# Out:
# True

# %% [markdown]
# ## Reinforcement Meta-Learning (REML) / "Learning to Learn by Gradient Descent as a Markov Deicision Process"

# %% [markdown]
# - layer pool
# - inner network -- composed of layers from layer pool
# - outer network (meta learner) -- responsible for parameters and hyperparameters of inner network

# %%
# create tasks
# (20, 100) shape
lower_bound = torch.tensor(-5).float()
upper_bound = torch.tensor(5).float()
X = np.linspace(lower_bound, upper_bound, config['N_X'])
amplitude_range = torch.tensor([0.1, 5.0]).float()
phase_range = torch.tensor([0, math.pi]).float()
amps = torch.from_numpy(np.linspace(amplitude_range[0], amplitude_range[1], config['N_TASKS'])).float()
phases = torch.from_numpy(np.linspace(phase_range[0], phase_range[1], config['N_TASKS'])).float()
tasks_data = torch.tensor([ 
        X
        for _ in range(config['N_TASKS'])
        ]).float()
tasks_targets = torch.tensor([
        [((a * np.sin(x)) + p).float()
        for x in X] 
        for a, p in zip(amps, phases)
        ]).float()
tasks_info = [
        [{'i' : i, 
         'amp' : a, 
         'phase_shift' : p, 
         'lower_bound' : lower_bound, 
         'upper_bound' : upper_bound, 
         'amplitude_range_lower_bound' : amplitude_range[0], 
         'amplitude_range_upper_bound' : amplitude_range[1], 
         'phase_range_lower_bound' : phase_range[0],
         'phase_range_lower_bound' : phase_range[1]}
         for _ in X]
        for i, (a, p) in enumerate(zip(amps, phases))
]

# %%
class RegressionModel(torch.nn.Module):
    def __init__(self):
        super(RegressionModel, self).__init__()
        self.layers = torch.nn.ModuleList([
            torch.nn.Linear(1, 32),  
            torch.nn.Linear(32, 32), 
            torch.nn.Linear(32, 32),  
            torch.nn.Linear(32, 1)  
        ])

    def forward(self, x):
        for i in range(len(self.layers)-1):
            x = torch.relu(self.layers[i](x))
        x = self.layers[-1](x)
        return x

# %%
layers = []
data = []
for x, y in zip(tasks_data, tasks_targets):
    data.append([x,y])
print(config)
print()
print(len(data))
print(len(data[0]))
fig, axs = plt.subplots(5, 2, figsize=(12, 15))
for i, (x, y) in enumerate(data):
    model = RegressionModel()
    criterion = torch.nn.MSELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

    # train before graphing
    num_epochs = 20000
    model.train()
    for epoch in range(num_epochs):
        optimizer.zero_grad() 
        outputs = model(x.view(-1, 1))
        loss = criterion(outputs, y.view(-1,1))
        loss.backward()
        optimizer.step()
    
    # get predicitons to graph
    model.eval()
    with torch.no_grad():
        outputs = model(x.view(-1, 1))
        test_loss = criterion(outputs, y.view(-1, 1))

    # graph truth vs. predictions
    row = i // 2
    col = i % 2
    axs[row, col].plot(x, y, label=f'Dataset {i + 1} (Actual)', linestyle='--', alpha=0.6)
    axs[row, col].plot(x, outputs.numpy(), label=f'Dataset {i + 1} (Predicted)')
    axs[row, col].set_title(f'Dataset {i + 1}')
    axs[row, col].legend()

    # save layers for layer pool
    layers.extend(model.layers)

plt.tight_layout()
plt.show()
# Out:
# {'SEED': 41, 'DEVICE': 'cuda', 'EPOCHS': 1, 'TIMESTEPS': 5000, 'N_X': 100, 'N_TASKS': 10, 'IN_FEATURES': 1, 'OUT_FEATURES': 1, 'POOL_N_LAYERS': 30, 'N_NODES_PER_LAYER': 32, 'POOL_LAYER_TYPE': <class 'torch.nn.modules.linear.Linear'>, 'ACTION_SPACE_SHAPE': (3,), 'EPSILON': 0.1, 'BATCH_SIZE': 1, 'LEARNING_RATE': 0.01, 'ACTION_CACHE_SIZE': 5, 'NUM_WORKERS': 0, 'LOSS_FN': MSELoss(), 'SB3_MODEL': <class 'sb3_contrib.ppo_recurrent.ppo_recurrent.RecurrentPPO'>, 'SB3_POLICY': 'MlpLstmPolicy'}
#
# 10
# 2

# %%
print(f'Layers saved: n={len(layers)}, layers={layers}')
# Out:
# Layers saved: n=40, layers=[Linear(in_features=1, out_features=32, bias=True), Linear(in_features=32, out_features=32, bias=True), Linear(in_features=32, out_features=32, bias=True), Linear(in_features=32, out_features=1, bias=True), Linear(in_features=1, out_features=32, bias=True), Linear(in_features=32, out_features=32, bias=True), Linear(in_features=32, out_features=32, bias=True), Linear(in_features=32, out_features=1, bias=True), Linear(in_features=1, out_features=32, bias=True), Linear(in_features=32, out_features=32, bias=True), Linear(in_features=32, out_features=32, bias=True), Linear(in_features=32, out_features=1, bias=True), Linear(in_features=1, out_features=32, bias=True), Linear(in_features=32, out_features=32, bias=True), Linear(in_features=32, out_features=32, bias=True), Linear(in_features=32, out_features=1, bias=True), Linear(in_features=1, out_features=32, bias=True), Linear(in_features=32, out_features=32, bias=True), Linear(in_features=32, out_features=32, bias=True), Linear(in_features=32, out_features=1, bias=True), Linear(in_features=1, out_features=32, bias=True), Linear(in_features=32, out_features=32, bias=True), Linear(in_features=32, out_features=32, bias=True), Linear(in_features=32, out_features=1, bias=True), Linear(in_features=1, out_features=32, bias=True), Linear(in_features=32, out_features=32, bias=True), Linear(in_features=32, out_features=32, bias=True), Linear(in_features=32, out_features=1, bias=True), Linear(in_features=1, out_features=32, bias=True), Linear(in_features=32, out_features=32, bias=True), Linear(in_features=32, out_features=32, bias=True), Linear(in_features=32, out_features=1, bias=True), Linear(in_features=1, out_features=32, bias=True), Linear(in_features=32, out_features=32, bias=True), Linear(in_features=32, out_features=32, bias=True), Linear(in_features=32, out_features=1, bias=True), Linear(in_features=1, out_features=32, bias=True), Linear(in_features=32, out_features=32, bias=True), Linear(in_features=32, out_features=32, bias=True), Linear(in_features=32, out_features=1, bias=True)]

# %%
class Layer:
    def __init__(self, 
                params: Type[torch.nn.Linear]=config['POOL_LAYER_TYPE']):
        self.params = params
        self.used = False
        self.times_used = 0

class LayerPool:
    # pool of uniform Layer objects each with the same type and shape
    def __init__(self, 
                size: int=config['POOL_N_LAYERS'], 
                layer_type: Type[torch.nn.Linear]=config['POOL_LAYER_TYPE'],
                in_features: int=config['IN_FEATURES'],
                out_features: int=config['OUT_FEATURES'],
                num_nodes_per_layer: int=config['N_NODES_PER_LAYER'],
                layers: List[torch.nn.Linear]=None):
        self.size = size if layers is None else len(layers)
        self.layer_type = layer_type
        self.in_features = in_features
        self.out_features = out_features
        self.num_nodes_per_layer = num_nodes_per_layer

        # if no layers are passed, create and initialize layer pool from scratch
        if layers is None:
            self.layers = {
                i : Layer(params=self.layer_type(in_features=num_nodes_per_layer, out_features=num_nodes_per_layer))
                for i in range(size)}
            for i in range(config['N_TASKS']):
                self.layers[size + i] = self.layer_type(in_features=in_features, out_features=num_nodes_per_layer)
            for i in range(config['N_TASKS']):
                self.layers[size + i] = self.layer_type(in_features=num_nodes_per_layer, out_features=out_features)
            [torch.nn.init.xavier_uniform_(layer.params.weight) for layer in self.layers.values()]
        else:
            self.layers = {
                i : Layer(params=layer) for i, layer in enumerate(layers)}
            config['POOL_N_LAYERS'] = len(self.layers)
        
    def __str__(self):
        return f"LayerPool(size={self.size}, layer_type={config['POOL_LAYER_TYPE']}, num_nodes_per_layer={config['N_NODES_PER_LAYER']}"

# %%
class InnerNetworkAction(Enum):
    NA = 0
    ADD = 1
    DELETE = 2
    ERROR = 3

# %%
class InnerNetworkTask(Dataset):
    def __init__(self, data, targets, info):
        self.data = data 
        self.targets = targets
        self.info = info

    def __len__(self):
        assert len(self.data) == config['N_X'], '[ERROR] Length should be the same as N_X.'
        return len(self.data)

    def __getitem__(self, index):
        assert self.data[index].dtype == torch.float32, f'[ERROR] Expected type torch.float32, got type: {self.data[index].dtype}'
        assert self.targets[index].dtype == torch.float32, f'[ERROR] Expected type torch.float32, got type: {self.targets[index].dtype}'
        sample = {
            'x' : self.data[index],
            'y' : self.targets[index],
            'info' : self.info[index]
        }
        return sample
    
    def __str__(self):
        return f'[INFO] InnerNetworkTask(data={self.data, self.targets}, info={self.info})'

# %%
class InnerNetwork(gym.Env, Module):
    def __init__(self, 
                task: InnerNetworkTask,
                layer_pool: LayerPool,
                in_features: int=config['IN_FEATURES'],
                out_features: int=config['OUT_FEATURES'],
                learning_rate: float=config['LEARNING_RATE'],
                batch_size: int=config['BATCH_SIZE'],
                epsilon: float=config['EPSILON'],
                action_cache_size: float=config['ACTION_CACHE_SIZE'],
                num_workers: int=config['NUM_WORKERS'],
                shuffle: bool=True,
                log_dir: str='runs',
                ):
        super(InnerNetwork, self).__init__()
        self.learning_rate = learning_rate
        self.epsilon = epsilon
        self.layer_pool = layer_pool
        self.task = task
        self.in_features = in_features
        self.out_features = out_features
        self.batch_size = batch_size
        self.shuffle = shuffle
        self.num_workers = num_workers
        self.data_loader = DataLoader(task, batch_size=batch_size, shuffle=shuffle, num_workers=num_workers)
        self.data_iter = iter(self.data_loader)
        self.prev = defaultdict(lambda: None)
        self.curr = defaultdict(lambda: None)

        # need to add initial and final layers for reset() and step() in case action is NA (i.e., train)
        self.initial_layer = random.choice([layer 
                                          for layer in self.layer_pool.layers.values() 
                                          if getattr(layer.params, 'in_features', None) == in_features])
        self.final_layer = random.choice([layer 
                                          for layer in self.layer_pool.layers.values() 
                                          if getattr(layer.params, 'out_features', None) == out_features])

        self.layers = torch.nn.ModuleList([self.initial_layer.params, self.final_layer.params]) 
        self.pool_indices = [] 
        self.loss_fn = torch.nn.MSELoss()
        self.opt = torch.optim.Adam(self.layers.parameters(), lr=self.learning_rate)
        self.action_cache_size = action_cache_size
        self.actions_taken = [InnerNetworkAction.NA] * config['ACTION_CACHE_SIZE']
        self.writer = SummaryWriter(log_dir=log_dir)
        self.cum_reward = 0
        self.timestep = 0
        self.end_condition = False
        self.state = self.reset()
        state_shape = self.build_state().shape
        self.observation_space = gym.spaces.box.Box(low=float('-inf'), high=float('inf'), shape=state_shape) # TODO is to normalize
        self.action_space = gym.spaces.discrete.Discrete(self.layer_pool.size * 3)


    def step(self, action: np.int64) -> Tuple[torch.Tensor, float, bool, dict]: 
        assert action.shape == (), f'[ERROR] Expected action shape () for scalar {self.action_space.n}, got: {action.shape}'
        assert action.dtype == np.int64, f'[ERROR] Expected np.int64 dtype, got: {action.dtype}'
        self.prev = self.curr
        self.curr = defaultdict(lambda: None)

        # RL updates network or not
        action = self.handle_action(action)
        self.update_inner_network(action)

        # run inner network and update values to build s'
        self.next_batch()
        self.curr['x'] = self.batch['x']
        self.curr['y'] = self.batch['y'] 
        self.curr['info'] = self.batch['info']
        self.forward_inner_network()
        s_prime = self.build_state()

        # calculate reward based on loss
        reward = self.reward()
        self.cum_reward += reward

        # log
        self.timestep += 1
        self.tensorboard_log()

        return (
            s_prime,
            reward, 
            self.end_condition, 
            self.end_condition,
            {}
        )
    
    def handle_action(self, action: np.int64) -> None:
        # take random action with epsilon probability
        if random.random() < self.epsilon: 
            action = random.randint(0, self.action_space.n - 1)

        # ADD action
        if (action < self.layer_pool.size):
            self.curr['action_type'] = InnerNetworkAction.ADD
            self.actions_taken.append(InnerNetworkAction.ADD)
        
        # DELETE action
        elif (action >= self.layer_pool.size and (action < self.layer_pool.size * 2)):
            # adjusting in this discrete action case to calculate pool indices
            adjusted_action_index = action - self.layer_pool.size
            # ERROR cases
            if adjusted_action_index not in self.pool_indices: 
                self.curr['action_type'] = InnerNetworkAction.ERROR
                self.actions_taken.append(InnerNetworkAction.ERROR)
            elif self.layer_pool.layers[adjusted_action_index].params.in_features==self.in_features or self.layer_pool.layers[adjusted_action_index].params.out_features==self.out_features:
                self.curr['action_type'] = InnerNetworkAction.ERROR
                self.actions_taken.append(InnerNetworkAction.ERROR)
            else:
                self.curr['action_type'] = InnerNetworkAction.DELETE
                self.actions_taken.append(InnerNetworkAction.DELETE)

        # NA Action
        else:
            self.curr['action_type'] = InnerNetworkAction.NA
            self.actions_taken.append(InnerNetworkAction.NA)
        
        return action 
    
    def update_inner_network(self, action: np.int64) -> None:
        if (self.curr['action_type']==InnerNetworkAction.ADD): 
            next_layer = self.layer_pool.layers[action].params
            self.pool_indices.append(action)
            # handle new initial layer
            if next_layer.in_features==self.in_features:
                self.layers.pop(0) 
                self.layers.insert(0, next_layer)
            # handle new final layer
            elif next_layer.out_features==self.out_features:
                final_layer = self.layers.pop(-1)
                self.layers.append(final_layer)
            # handle hidden layers
            else:
                final_layer = self.layers.pop(-1) 
                self.layers.append(next_layer)  
                self.layers.append(final_layer) 
        elif (self.curr['action_type']==InnerNetworkAction.DELETE):
            adjusted_action_index = action - self.layer_pool.size
            self.pool_indices.remove(adjusted_action_index)
            layer_to_delete_weights = self.layer_pool.layers[adjusted_action_index].params
            network_index = self.get_layer_index(layer_to_delete_weights)
            assert layer_to_delete_weights == self.layers[network_index], '[ERROR] Wrong layer would be deleted from inner network params.'
            self.layers.pop(network_index)
        elif (self.curr['action_type']==InnerNetworkAction.NA or self.curr['action_type']==InnerNetworkAction.ERROR):
            return # no architecture updates / only train this timestep
        else: 
            raise Exception(f"[ERROR] Unexpected action returned by inner network: {self.curr['action_type']}")

    def get_layer_index(self, target_weights: torch.nn.Linear) -> int:
        for i, layer in enumerate(self.layers):
            if isinstance(layer, torch.nn.Linear) and \
            torch.all(torch.eq(layer.weight, target_weights.weight)) and \
            torch.all(torch.eq(layer.bias, target_weights.bias)):
                return i
        return -1 
            
    def next_batch(self, throw_exception=False) -> None:
        if (throw_exception):
            return next(self.data_iter)
        else: 
            try:
                self.batch = next(self.data_iter)
            except StopIteration:
                self.data_loader = DataLoader(self.task, batch_size=self.batch_size, shuffle=self.shuffle, num_workers=self.num_workers)
                self.data_iter = iter(self.data_loader)
                self.batch = next(self.data_iter)

    def forward_inner_network(self, train=True) -> None: 

        def _forward():
            x = self.curr['x']
            for i in range(len(self.layers) - 1): x = torch.nn.functional.relu(self.layers[i](x))
            self.curr['latent_space'] = x
            self.curr['y_hat'] = self.layers[-1](x) 
            self.curr['prev_loss'] = self.curr['loss']
            self.curr['loss'] = self.loss_fn(self.curr['y'], self.curr['y_hat'])
            assert self.curr['latent_space'].dtype == torch.float32
            assert self.curr['y_hat'].dtype == torch.float32

        if train:
            self.train() # call before _forward to save gradient data for backward() 
            self.opt = torch.optim.Adam(self.layers.parameters(), lr=self.learning_rate) 
            self.opt.zero_grad()
            _forward()
            loss = self.curr['loss']
            loss.backward()
            self.opt.step()
        else:
            self.eval()
            _forward()

    def build_state(self) -> np.ndarray:
        one_hot_network_layers = torch.tensor(np.array([1 if self.layer_pool.layers[i].params in self.layers else 0 
                                   for i in range(len(self.layer_pool.layers))]))
        # sequence_network_layers = torch.tensor(np.array([index + 1 for index in self.pool_indices] + [0] * (self.layer_pool.size - len(self.pool_indices))))
        num_add_actions = torch.tensor(len(list(filter(lambda e : e == InnerNetworkAction.ADD, self.actions_taken)))).unsqueeze(0)
        num_delete_actions = torch.tensor(len(list(filter(lambda e : e == InnerNetworkAction.DELETE, self.actions_taken)))).unsqueeze(0)
        num_layers = torch.tensor(len(self.layers)).unsqueeze(0)
        h = torch.tensor([action_enum.value for action_enum in self.actions_taken[-self.action_cache_size:]])
        task_info = torch.tensor([float(value) for value in self.curr['info'].values()])
        return torch.concat((
            # about the task
            task_info,
            self.curr['x'],

            # about the inner network's choices
            self.curr['latent_space'],
            self.curr['y'],
            self.curr['y_hat'],

            # about the meta network's choices
            one_hot_network_layers,
            num_add_actions,
            num_delete_actions,
            num_layers,
            h
        ), dim=0).detach().numpy()
    
    def reward(self) -> torch.Tensor:
        prev_loss = self.curr['prev_loss'] or None
        curr_loss = self.curr['loss']
        loss_delta = prev_loss - curr_loss if prev_loss is not None else curr_loss
        if (self.curr['action_type'] == InnerNetworkAction.ADD):
            reward = loss_delta / math.sqrt(len(self.layers))
        elif (self.curr['action_type'] == InnerNetworkAction.DELETE or self.curr['action_type'] == InnerNetworkAction.NA):
            reward = loss_delta
        elif (self.curr['action_type'] == InnerNetworkAction.ERROR):
            reward = -1000
        else:
            raise Exception('[ERROR] Invalid action type.')
        self.curr['reward'] = reward
        return reward

    def tensorboard_log(self):
        task_num = str(self.curr['info']['i'].item())
        self.writer.add_scalar(f'loss_{task_num}', self.curr['loss'], global_step=self.timestep) 
        self.writer.add_scalar(f'num_layers_{task_num}', len(self.layers), global_step=self.timestep) 
        self.writer.add_scalar(f'reward_{task_num}', self.curr['reward'], global_step=self.timestep)
        if (len(self.pool_indices)!=0):
            self.writer.add_histogram(f'pool_indices_{task_num}', torch.tensor(self.pool_indices).long(), global_step=self.timestep) 
        self.writer.add_histogram(f'action_types_{task_num}', torch.tensor([e.value for e in self.actions_taken]).long(), global_step=self.timestep) 

    def reset(self, seed=None) -> np.ndarray:
        self.next_batch()
        self.curr['x'] = self.batch['x']
        self.curr['y'] = self.batch['y'] 
        self.curr['info'] = self.batch['info']
        self.forward_inner_network(train=False)
        return self.build_state(), None

# %%
class REML:
    def __init__(
        self,
        layer_pool: LayerPool,
        tasks: List[InnerNetworkTask],
        model=config['SB3_MODEL'],
        policy=config['SB3_POLICY'],
        epochs: int=config['EPOCHS'],
        timesteps: int=config['TIMESTEPS'],
        device: str=config['DEVICE'],
        overwrite: bool=True,  # TODO is to revisit this param
        intra_update: bool=True, # TODO is to revisit this param
        log_dir: str='runs',
        ):
        self.layer_pool = layer_pool
        self.tasks = tasks
        self.model = model
        self.policy = policy
        self.epochs = epochs
        self.timesteps = timesteps
        self.device = device
        self.overwrite = overwrite 
        self.intra_update = intra_update
        self.log_dir = log_dir
    
    def __str__(self):
        return f'REML(model={self.model}, policy={self.policy})'

    def train(self):
        # wraps stablebaselines learn() so we call it n * m times
        # n is the number of epochs where we run all m tasks
        # we use the same policy, swapping out envs for the n tasks, m times. 
        # therefore the number of steps is (timesteps)*(n)*(m)
        first_run = True
        for epoch in range(self.epochs):
            print(f'[INFO] Epoch {epoch + 1}/{self.epochs}')
            for i, task in enumerate(self.tasks): 
                print(f'[INFO] Task num={i+1}/{len(self.tasks)}')

                # each task gets its own network
                self.env = InnerNetwork(task, self.layer_pool, log_dir=self.log_dir)
                if first_run: 
                    model = self.model(self.policy, 
                                       self.env,
                                       n_steps=config['N_X'],
                                       tensorboard_log=self.log_dir,
                                       verbose=1,)
                    first_run = False
                    
                else: 
                    model.set_env(self.env)

                # train meta learner on task
                model.learn(total_timesteps=self.timesteps, 
                            tb_log_name=f'epoch_{epoch}_task_{i}',
                            reset_num_timesteps=True)

                # epoch log
                self.env.writer.add_scalar(f'loss/epoch_{epoch}_task_{i}', self.env.curr['loss'], global_step=epoch) 
                self.env.writer.add_scalar(f'cumulative_reward/epoch_{epoch}_task_{i}', self.env.cum_reward, global_step=epoch) 
                yhats = self.evaluate_inner_network()
                for x, yhat in zip(self.env.task.data, yhats):
                    self.env.writer.add_scalar(f'sin_curve/epoch_{epoch}', yhat, global_step=x)
                self.env.writer.close()

                # update pool
                # for i in range(len(self.env.pool_indices)):
                #     pool_index = self.env.pool_indices[i]
                #     updated_layer_copy = self.env.layers[i+1]
                #     self.layer_pool.layers[pool_index].params = updated_layer_copy
                #     self.layer_pool.layers[pool_index].used = True
                #     self.layer_pool.layers[pool_index].times_used += 1
    
    def evaluate_inner_network(self):
        self.env.eval()
        y_hats = []
        try:
            # reset data_iter for full dataset 
            self.env.data_loader = DataLoader(self.env.task, batch_size=self.env.batch_size, shuffle=self.env.shuffle, num_workers=self.env.num_workers)
            self.env.data_iter = iter(self.env.data_loader)
            while True:
                batch = self.env.next_batch(throw_exception=True)
                x = batch['x']
                for i in range(len(self.env.layers)-1):
                    x = torch.nn.functional.relu(self.env.layers[i](x))
                x = self.env.layers[-1](x) # do not relu the very last calculation
                y_hats.append(x)
        except StopIteration:
            pass
        return y_hats

# %% [markdown]
# ### testing
# However, 2 epoch is still going through all 20 tasks, generating 20 different networks, using the same 1 meta policy. Also, on each task we loop through the data 1000 times (timesteps / len(X) == 10000 / 100).
# <br>
# The benefit of more epochs is we get the meta policy to gnerate 20 different networks again for the 20 tasks, having hopefully learned something from the first run.

# %% [markdown]
# ### sinusoidal curves regression as in 2018 MAML paper

# %%
# create tasks
lower_bound = torch.tensor(-5).float()
upper_bound = torch.tensor(5).float()
X = np.linspace(lower_bound, upper_bound, config['N_X'])
amplitude_range = torch.tensor([0.1, 5.0]).float()
phase_range = torch.tensor([0, math.pi]).float()
amps = torch.from_numpy(np.linspace(amplitude_range[0], amplitude_range[1], config['N_TASKS'])).float()
phases = torch.from_numpy(np.linspace(phase_range[0], phase_range[1], config['N_TASKS'])).float()

# (20, 100)
tasks_data = torch.tensor([ 
        X
        for _ in range(config['N_TASKS'])
        ]).float()
tasks_targets = torch.tensor([
        [((a * np.sin(x)) + p).float()
        for x in X] 
        for a, p in zip(amps, phases)
        ]).float()
tasks_info = [
        [{'i' : i, 
         'amp' : a, 
         'phase_shift' : p, 
         'lower_bound' : lower_bound, 
         'upper_bound' : upper_bound, 
         'amplitude_range_lower_bound' : amplitude_range[0], 
         'amplitude_range_upper_bound' : amplitude_range[1], 
         'phase_range_lower_bound' : phase_range[0],
         'phase_range_lower_bound' : phase_range[1]}
         for _ in X]
        for i, (a, p) in enumerate(zip(amps, phases))
]

# %%
print(tasks_data.shape)
print(tasks_data.dtype)
print(tasks_targets.shape)
print(tasks_targets.dtype)
print(len(tasks_info))
print(len(tasks_info[0]))
# Out:
# torch.Size([5, 100])
# torch.float32
# torch.Size([5, 100])
# torch.float32
# 5
# 100

# %%
# run
tasks = [InnerNetworkTask(data=tasks_data[i], targets=tasks_targets[i], info=tasks_info[i]) for i in range(config['N_TASKS'])]
pool = LayerPool(layers=layers)
log_dir = f'./runs/ppo_{datetime.datetime.now().strftime("%Y-%m-%d_%H-%M-%S")}'
model = REML(layer_pool=pool, tasks=tasks, log_dir=log_dir)

# %%
model.__str__()
# Out:
# "REML(model=<class 'sb3_contrib.ppo_recurrent.ppo_recurrent.RecurrentPPO'>, policy=MlpLstmPolicy)"

# %%
model.train()
# Out:
# [INFO] Epoch 1/2
# [INFO] Task num=1/5
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to ./runs/ppo_2023-10-21_20-08-13\epoch_0_task_0_1
# ----------------------------
# | time/              |     |
# |    fps             | 78  |
# |    iterations      | 1   |
# |    time_elapsed    | 1   |
# |    total_timesteps | 100 |
# ----------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 46            |
# |    iterations           | 2             |
# |    time_elapsed         | 4             |
# |    total_timesteps      | 200           |
# | train/                  |               |
# |    approx_kl            | 5.2452087e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.79         |
# |    explained_variance   | -0.000268     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.31e+07      |
# |    n_updates            | 10            |
# |    policy_gradient_loss | -0.000118     |
# |    value_loss           | 2.62e+07      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 47            |
# |    iterations           | 3             |
# |    time_elapsed         | 6             |
# |    total_timesteps      | 300           |
# | train/                  |               |
# |    approx_kl            | 1.1801719e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.79         |
# |    explained_variance   | 0.000264      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 7.7e+06       |
# |    n_updates            | 20            |
# |    policy_gradient_loss | -0.000111     |
# |    value_loss           | 1.54e+07      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 50           |
# |    iterations           | 4            |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 400          |
# | train/                  |              |
# |    approx_kl            | 8.463859e-08 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.79        |
# |    explained_variance   | 6e-05        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.32e+06     |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.000102    |
# |    value_loss           | 1.66e+07     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 51            |
# |    iterations           | 5             |
# |    time_elapsed         | 9             |
# |    total_timesteps      | 500           |
# | train/                  |               |
# |    approx_kl            | 1.7523764e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.79         |
# |    explained_variance   | 7.33e-06      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 5.35e+06      |
# |    n_updates            | 40            |
# |    policy_gradient_loss | -0.000146     |
# |    value_loss           | 1.07e+07      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 50            |
# |    iterations           | 6             |
# |    time_elapsed         | 11            |
# |    total_timesteps      | 600           |
# | train/                  |               |
# |    approx_kl            | 3.2961367e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.79         |
# |    explained_variance   | 5.9e-06       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.45e+06      |
# |    n_updates            | 50            |
# |    policy_gradient_loss | -0.000222     |
# |    value_loss           | 6.9e+06       |
# -------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 50          |
# |    iterations           | 7           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 700         |
# | train/                  |             |
# |    approx_kl            | 6.29425e-07 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.79       |
# |    explained_variance   | 2.68e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.65e+06    |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.000321   |
# |    value_loss           | 7.29e+06    |
# -----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 50            |
# |    iterations           | 8             |
# |    time_elapsed         | 15            |
# |    total_timesteps      | 800           |
# | train/                  |               |
# |    approx_kl            | 2.5510786e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.79         |
# |    explained_variance   | 1.01e-06      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 8.77e+06      |
# |    n_updates            | 70            |
# |    policy_gradient_loss | -0.000122     |
# |    value_loss           | 1.75e+07      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 50            |
# |    iterations           | 9             |
# |    time_elapsed         | 17            |
# |    total_timesteps      | 900           |
# | train/                  |               |
# |    approx_kl            | 1.8775462e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.79         |
# |    explained_variance   | 2.98e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 6.43e+06      |
# |    n_updates            | 80            |
# |    policy_gradient_loss | -0.000136     |
# |    value_loss           | 1.29e+07      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 49            |
# |    iterations           | 10            |
# |    time_elapsed         | 20            |
# |    total_timesteps      | 1000          |
# | train/                  |               |
# |    approx_kl            | 1.7881393e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.79         |
# |    explained_variance   | 1.19e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.64e+06      |
# |    n_updates            | 90            |
# |    policy_gradient_loss | -0.000145     |
# |    value_loss           | 7.27e+06      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 49            |
# |    iterations           | 11            |
# |    time_elapsed         | 22            |
# |    total_timesteps      | 1100          |
# | train/                  |               |
# |    approx_kl            | 2.1934508e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.79         |
# |    explained_variance   | 1.19e-06      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 6.89e+06      |
# |    n_updates            | 100           |
# |    policy_gradient_loss | -0.000147     |
# |    value_loss           | 1.38e+07      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 48            |
# |    iterations           | 12            |
# |    time_elapsed         | 24            |
# |    total_timesteps      | 1200          |
# | train/                  |               |
# |    approx_kl            | 3.0577183e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.79         |
# |    explained_variance   | 4.17e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.94e+06      |
# |    n_updates            | 110           |
# |    policy_gradient_loss | -0.000224     |
# |    value_loss           | 5.87e+06      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 48            |
# |    iterations           | 13            |
# |    time_elapsed         | 26            |
# |    total_timesteps      | 1300          |
# | train/                  |               |
# |    approx_kl            | 3.7074088e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.79         |
# |    explained_variance   | 3.1e-06       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.54e+06      |
# |    n_updates            | 120           |
# |    policy_gradient_loss | -0.000219     |
# |    value_loss           | 5.08e+06      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 48            |
# |    iterations           | 14            |
# |    time_elapsed         | 29            |
# |    total_timesteps      | 1400          |
# | train/                  |               |
# |    approx_kl            | 3.3199785e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.79         |
# |    explained_variance   | -7.15e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.02e+06      |
# |    n_updates            | 130           |
# |    policy_gradient_loss | -0.000163     |
# |    value_loss           | 8.04e+06      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 47           |
# |    iterations           | 15           |
# |    time_elapsed         | 31           |
# |    total_timesteps      | 1500         |
# | train/                  |              |
# |    approx_kl            | 3.540516e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.79        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.86e+06     |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.000227    |
# |    value_loss           | 5.73e+06     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 47            |
# |    iterations           | 16            |
# |    time_elapsed         | 33            |
# |    total_timesteps      | 1600          |
# | train/                  |               |
# |    approx_kl            | 3.0398368e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.79         |
# |    explained_variance   | 1.79e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.28e+06      |
# |    n_updates            | 150           |
# |    policy_gradient_loss | -0.000149     |
# |    value_loss           | 6.56e+06      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 46            |
# |    iterations           | 17            |
# |    time_elapsed         | 36            |
# |    total_timesteps      | 1700          |
# | train/                  |               |
# |    approx_kl            | 4.1365624e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.79         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.43e+06      |
# |    n_updates            | 160           |
# |    policy_gradient_loss | -0.000251     |
# |    value_loss           | 8.87e+06      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 44            |
# |    iterations           | 18            |
# |    time_elapsed         | 40            |
# |    total_timesteps      | 1800          |
# | train/                  |               |
# |    approx_kl            | 4.8935414e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.79         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.07e+06      |
# |    n_updates            | 170           |
# |    policy_gradient_loss | -0.000278     |
# |    value_loss           | 4.14e+06      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 43            |
# |    iterations           | 19            |
# |    time_elapsed         | 43            |
# |    total_timesteps      | 1900          |
# | train/                  |               |
# |    approx_kl            | 4.4345856e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.79         |
# |    explained_variance   | 1.79e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 5.32e+06      |
# |    n_updates            | 180           |
# |    policy_gradient_loss | -0.0002       |
# |    value_loss           | 1.06e+07      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 42           |
# |    iterations           | 20           |
# |    time_elapsed         | 46           |
# |    total_timesteps      | 2000         |
# | train/                  |              |
# |    approx_kl            | 6.687641e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.79        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.96e+05     |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.000296    |
# |    value_loss           | 1.99e+06     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 42           |
# |    iterations           | 21           |
# |    time_elapsed         | 49           |
# |    total_timesteps      | 2100         |
# | train/                  |              |
# |    approx_kl            | 7.748604e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.79        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.32e+06     |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.000298    |
# |    value_loss           | 8.64e+06     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 42            |
# |    iterations           | 22            |
# |    time_elapsed         | 52            |
# |    total_timesteps      | 2200          |
# | train/                  |               |
# |    approx_kl            | 4.4345856e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.79         |
# |    explained_variance   | 6.56e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.5e+06       |
# |    n_updates            | 210           |
# |    policy_gradient_loss | -0.000235     |
# |    value_loss           | 7e+06         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 41            |
# |    iterations           | 23            |
# |    time_elapsed         | 55            |
# |    total_timesteps      | 2300          |
# | train/                  |               |
# |    approx_kl            | 3.2842158e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.79         |
# |    explained_variance   | 1.79e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.24e+06      |
# |    n_updates            | 220           |
# |    policy_gradient_loss | -0.000168     |
# |    value_loss           | 8.47e+06      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 41           |
# |    iterations           | 24           |
# |    time_elapsed         | 57           |
# |    total_timesteps      | 2400         |
# | train/                  |              |
# |    approx_kl            | 2.449751e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.79        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.44e+06     |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.000157    |
# |    value_loss           | 1.09e+07     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 41            |
# |    iterations           | 25            |
# |    time_elapsed         | 60            |
# |    total_timesteps      | 2500          |
# | train/                  |               |
# |    approx_kl            | 3.7014485e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.79         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.17e+06      |
# |    n_updates            | 240           |
# |    policy_gradient_loss | -0.000226     |
# |    value_loss           | 4.34e+06      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 40            |
# |    iterations           | 26            |
# |    time_elapsed         | 63            |
# |    total_timesteps      | 2600          |
# | train/                  |               |
# |    approx_kl            | 2.3841858e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.79         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 6.49e+06      |
# |    n_updates            | 250           |
# |    policy_gradient_loss | -0.000106     |
# |    value_loss           | 1.3e+07       |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 40            |
# |    iterations           | 27            |
# |    time_elapsed         | 66            |
# |    total_timesteps      | 2700          |
# | train/                  |               |
# |    approx_kl            | 2.3961067e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.79         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 5.27e+06      |
# |    n_updates            | 260           |
# |    policy_gradient_loss | -0.000192     |
# |    value_loss           | 1.05e+07      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 40           |
# |    iterations           | 28           |
# |    time_elapsed         | 69           |
# |    total_timesteps      | 2800         |
# | train/                  |              |
# |    approx_kl            | 4.249811e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.79        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.34e+06     |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.00024     |
# |    value_loss           | 6.68e+06     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 40           |
# |    iterations           | 29           |
# |    time_elapsed         | 72           |
# |    total_timesteps      | 2900         |
# | train/                  |              |
# |    approx_kl            | 2.837181e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.79        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.63e+06     |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.000205    |
# |    value_loss           | 9.25e+06     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 40           |
# |    iterations           | 30           |
# |    time_elapsed         | 74           |
# |    total_timesteps      | 3000         |
# | train/                  |              |
# |    approx_kl            | 3.427267e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.79        |
# |    explained_variance   | 5.96e-08     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.1e+06      |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.00021     |
# |    value_loss           | 6.19e+06     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 39           |
# |    iterations           | 31           |
# |    time_elapsed         | 77           |
# |    total_timesteps      | 3100         |
# | train/                  |              |
# |    approx_kl            | 2.580881e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.79        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.99e+06     |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.000122    |
# |    value_loss           | 1.6e+07      |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 39            |
# |    iterations           | 32            |
# |    time_elapsed         | 80            |
# |    total_timesteps      | 3200          |
# | train/                  |               |
# |    approx_kl            | 3.1113623e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.79         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.94e+06      |
# |    n_updates            | 310           |
# |    policy_gradient_loss | -0.000233     |
# |    value_loss           | 5.88e+06      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 39            |
# |    iterations           | 33            |
# |    time_elapsed         | 83            |
# |    total_timesteps      | 3300          |
# | train/                  |               |
# |    approx_kl            | 1.4293194e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.79         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.15e+06      |
# |    n_updates            | 320           |
# |    policy_gradient_loss | -0.000432     |
# |    value_loss           | 2.3e+06       |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 39           |
# |    iterations           | 34           |
# |    time_elapsed         | 86           |
# |    total_timesteps      | 3400         |
# | train/                  |              |
# |    approx_kl            | 6.395578e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.79        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.51e+06     |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.000262    |
# |    value_loss           | 5.01e+06     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 39           |
# |    iterations           | 35           |
# |    time_elapsed         | 89           |
# |    total_timesteps      | 3500         |
# | train/                  |              |
# |    approx_kl            | 3.117323e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.79        |
# |    explained_variance   | 5.96e-08     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.77e+06     |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.000178    |
# |    value_loss           | 1.15e+07     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 39           |
# |    iterations           | 36           |
# |    time_elapsed         | 92           |
# |    total_timesteps      | 3600         |
# | train/                  |              |
# |    approx_kl            | 2.104044e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.79        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.58e+06     |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.000143    |
# |    value_loss           | 1.32e+07     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 39           |
# |    iterations           | 37           |
# |    time_elapsed         | 94           |
# |    total_timesteps      | 3700         |
# | train/                  |              |
# |    approx_kl            | 2.515316e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.79        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.84e+06     |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.000174    |
# |    value_loss           | 9.68e+06     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 38           |
# |    iterations           | 38           |
# |    time_elapsed         | 97           |
# |    total_timesteps      | 3800         |
# | train/                  |              |
# |    approx_kl            | 3.540516e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.79        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.55e+06     |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.000189    |
# |    value_loss           | 7.09e+06     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 38            |
# |    iterations           | 39            |
# |    time_elapsed         | 100           |
# |    total_timesteps      | 3900          |
# | train/                  |               |
# |    approx_kl            | 2.9206277e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.79         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.35e+06      |
# |    n_updates            | 380           |
# |    policy_gradient_loss | -0.000142     |
# |    value_loss           | 8.7e+06       |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 38            |
# |    iterations           | 40            |
# |    time_elapsed         | 102           |
# |    total_timesteps      | 4000          |
# | train/                  |               |
# |    approx_kl            | 4.2557716e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.79         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.73e+06      |
# |    n_updates            | 390           |
# |    policy_gradient_loss | -0.000246     |
# |    value_loss           | 5.46e+06      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 38           |
# |    iterations           | 41           |
# |    time_elapsed         | 105          |
# |    total_timesteps      | 4100         |
# | train/                  |              |
# |    approx_kl            | 4.816055e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.79        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.11e+06     |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -0.000264    |
# |    value_loss           | 8.22e+06     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 38           |
# |    iterations           | 42           |
# |    time_elapsed         | 108          |
# |    total_timesteps      | 4200         |
# | train/                  |              |
# |    approx_kl            | 5.185604e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.79        |
# |    explained_variance   | 1.19e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.05e+06     |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.000265    |
# |    value_loss           | 4.11e+06     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 38           |
# |    iterations           | 43           |
# |    time_elapsed         | 111          |
# |    total_timesteps      | 4300         |
# | train/                  |              |
# |    approx_kl            | 5.304813e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.79        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.06e+06     |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.000239    |
# |    value_loss           | 6.11e+06     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 38            |
# |    iterations           | 44            |
# |    time_elapsed         | 114           |
# |    total_timesteps      | 4400          |
# | train/                  |               |
# |    approx_kl            | 5.0723554e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.79         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.09e+06      |
# |    n_updates            | 430           |
# |    policy_gradient_loss | -0.00027      |
# |    value_loss           | 4.18e+06      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 38            |
# |    iterations           | 45            |
# |    time_elapsed         | 117           |
# |    total_timesteps      | 4500          |
# | train/                  |               |
# |    approx_kl            | 4.8458577e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.79         |
# |    explained_variance   | 1.19e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.52e+06      |
# |    n_updates            | 440           |
# |    policy_gradient_loss | -0.000238     |
# |    value_loss           | 7.03e+06      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 38           |
# |    iterations           | 46           |
# |    time_elapsed         | 120          |
# |    total_timesteps      | 4600         |
# | train/                  |              |
# |    approx_kl            | 4.661083e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.79        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.38e+06     |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -0.000233    |
# |    value_loss           | 4.76e+06     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 38           |
# |    iterations           | 47           |
# |    time_elapsed         | 123          |
# |    total_timesteps      | 4700         |
# | train/                  |              |
# |    approx_kl            | 4.529953e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.79        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.89e+06     |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.000203    |
# |    value_loss           | 7.78e+06     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 38           |
# |    iterations           | 48           |
# |    time_elapsed         | 125          |
# |    total_timesteps      | 4800         |
# | train/                  |              |
# |    approx_kl            | 5.829334e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.79        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.06e+06     |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.000224    |
# |    value_loss           | 1.21e+07     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 38            |
# |    iterations           | 49            |
# |    time_elapsed         | 128           |
# |    total_timesteps      | 4900          |
# | train/                  |               |
# |    approx_kl            | 1.4007091e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.79         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.16e+07      |
# |    n_updates            | 480           |
# |    policy_gradient_loss | -0.000109     |
# |    value_loss           | 2.33e+07      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 37            |
# |    iterations           | 50            |
# |    time_elapsed         | 131           |
# |    total_timesteps      | 5000          |
# | train/                  |               |
# |    approx_kl            | 1.6927719e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.79         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1e+07         |
# |    n_updates            | 490           |
# |    policy_gradient_loss | -0.000146     |
# |    value_loss           | 2.01e+07      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 37           |
# |    iterations           | 51           |
# |    time_elapsed         | 134          |
# |    total_timesteps      | 5100         |
# | train/                  |              |
# |    approx_kl            | 4.607439e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.79        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.73e+06     |
# |    n_updates            | 500          |
# |    policy_gradient_loss | -0.000263    |
# |    value_loss           | 7.46e+06     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 37            |
# |    iterations           | 52            |
# |    time_elapsed         | 137           |
# |    total_timesteps      | 5200          |
# | train/                  |               |
# |    approx_kl            | 3.3795834e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.79         |
# |    explained_variance   | 5.96e-08      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 5.27e+06      |
# |    n_updates            | 510           |
# |    policy_gradient_loss | -0.000146     |
# |    value_loss           | 1.05e+07      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 37            |
# |    iterations           | 53            |
# |    time_elapsed         | 140           |
# |    total_timesteps      | 5300          |
# | train/                  |               |
# |    approx_kl            | 2.8192997e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.79         |
# |    explained_variance   | 5.96e-08      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 5.78e+06      |
# |    n_updates            | 520           |
# |    policy_gradient_loss | -0.000201     |
# |    value_loss           | 1.16e+07      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 37            |
# |    iterations           | 54            |
# |    time_elapsed         | 143           |
# |    total_timesteps      | 5400          |
# | train/                  |               |
# |    approx_kl            | 3.1411648e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.79         |
# |    explained_variance   | 1.19e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.44e+06      |
# |    n_updates            | 530           |
# |    policy_gradient_loss | -0.00018      |
# |    value_loss           | 4.89e+06      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 37            |
# |    iterations           | 55            |
# |    time_elapsed         | 146           |
# |    total_timesteps      | 5500          |
# | train/                  |               |
# |    approx_kl            | 2.7060509e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.79         |
# |    explained_variance   | 5.96e-08      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.31e+06      |
# |    n_updates            | 540           |
# |    policy_gradient_loss | -0.000164     |
# |    value_loss           | 8.62e+06      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 37           |
# |    iterations           | 56           |
# |    time_elapsed         | 149          |
# |    total_timesteps      | 5600         |
# | train/                  |              |
# |    approx_kl            | 3.147125e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.79        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.93e+06     |
# |    n_updates            | 550          |
# |    policy_gradient_loss | -0.000149    |
# |    value_loss           | 1.39e+07     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 37            |
# |    iterations           | 57            |
# |    time_elapsed         | 152           |
# |    total_timesteps      | 5700          |
# | train/                  |               |
# |    approx_kl            | 3.1411648e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.79         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.19e+06      |
# |    n_updates            | 560           |
# |    policy_gradient_loss | -0.000188     |
# |    value_loss           | 6.38e+06      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 37            |
# |    iterations           | 58            |
# |    time_elapsed         | 156           |
# |    total_timesteps      | 5800          |
# | train/                  |               |
# |    approx_kl            | 3.8325786e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.79         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 6.71e+06      |
# |    n_updates            | 570           |
# |    policy_gradient_loss | -0.000218     |
# |    value_loss           | 1.34e+07      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 37            |
# |    iterations           | 59            |
# |    time_elapsed         | 159           |
# |    total_timesteps      | 5900          |
# | train/                  |               |
# |    approx_kl            | 2.2828578e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.79         |
# |    explained_variance   | 1.19e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 6.55e+06      |
# |    n_updates            | 580           |
# |    policy_gradient_loss | -0.000151     |
# |    value_loss           | 1.31e+07      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 36            |
# |    iterations           | 60            |
# |    time_elapsed         | 162           |
# |    total_timesteps      | 6000          |
# | train/                  |               |
# |    approx_kl            | 3.6895275e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.79         |
# |    explained_variance   | 1.19e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 5.74e+06      |
# |    n_updates            | 590           |
# |    policy_gradient_loss | -0.000206     |
# |    value_loss           | 1.15e+07      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 36            |
# |    iterations           | 61            |
# |    time_elapsed         | 165           |
# |    total_timesteps      | 6100          |
# | train/                  |               |
# |    approx_kl            | 2.5629996e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.79         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.33e+06      |
# |    n_updates            | 600           |
# |    policy_gradient_loss | -0.000162     |
# |    value_loss           | 8.67e+06      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 36           |
# |    iterations           | 62           |
# |    time_elapsed         | 169          |
# |    total_timesteps      | 6200         |
# | train/                  |              |
# |    approx_kl            | 6.955862e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.79        |
# |    explained_variance   | -1.19e-07    |
# ...
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.04e+06      |
# |    n_updates            | 3290          |
# |    policy_gradient_loss | -0.000414     |
# |    value_loss           | 4.08e+06      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 18           |
# |    iterations           | 131          |
# |    time_elapsed         | 708          |
# |    total_timesteps      | 13100        |
# | train/                  |              |
# |    approx_kl            | 6.741285e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.78        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.86e+06     |
# |    n_updates            | 3300         |
# |    policy_gradient_loss | -0.00027     |
# |    value_loss           | 3.71e+06     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 18            |
# |    iterations           | 132           |
# |    time_elapsed         | 717           |
# |    total_timesteps      | 13200         |
# | train/                  |               |
# |    approx_kl            | 7.5757504e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.78         |
# |    explained_variance   | 1.19e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.58e+06      |
# |    n_updates            | 3310          |
# |    policy_gradient_loss | -0.000303     |
# |    value_loss           | 5.17e+06      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 18            |
# |    iterations           | 133           |
# |    time_elapsed         | 726           |
# |    total_timesteps      | 13300         |
# | train/                  |               |
# |    approx_kl            | 1.2969971e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.78         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.72e+06      |
# |    n_updates            | 3320          |
# |    policy_gradient_loss | -0.000401     |
# |    value_loss           | 3.44e+06      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 18            |
# |    iterations           | 134           |
# |    time_elapsed         | 735           |
# |    total_timesteps      | 13400         |
# | train/                  |               |
# |    approx_kl            | 6.8366523e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.78         |
# |    explained_variance   | 1.19e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 5.14e+06      |
# |    n_updates            | 3330          |
# |    policy_gradient_loss | -0.000263     |
# |    value_loss           | 1.03e+07      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 18           |
# |    iterations           | 135          |
# |    time_elapsed         | 745          |
# |    total_timesteps      | 13500        |
# | train/                  |              |
# |    approx_kl            | 9.220838e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.78        |
# |    explained_variance   | 1.79e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.39e+06     |
# |    n_updates            | 3340         |
# |    policy_gradient_loss | -0.000363    |
# |    value_loss           | 2.79e+06     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 18            |
# |    iterations           | 136           |
# |    time_elapsed         | 754           |
# |    total_timesteps      | 13600         |
# | train/                  |               |
# |    approx_kl            | 9.2864036e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.78         |
# |    explained_variance   | 2.38e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.19e+06      |
# |    n_updates            | 3350          |
# |    policy_gradient_loss | -0.000356     |
# |    value_loss           | 4.38e+06      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 17           |
# |    iterations           | 137          |
# |    time_elapsed         | 764          |
# |    total_timesteps      | 13700        |
# | train/                  |              |
# |    approx_kl            | 1.206398e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.78        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.87e+06     |
# |    n_updates            | 3360         |
# |    policy_gradient_loss | -0.000379    |
# |    value_loss           | 3.74e+06     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 17           |
# |    iterations           | 138          |
# |    time_elapsed         | 773          |
# |    total_timesteps      | 13800        |
# | train/                  |              |
# |    approx_kl            | 6.020069e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.78        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.05e+06     |
# |    n_updates            | 3370         |
# |    policy_gradient_loss | -0.000257    |
# |    value_loss           | 6.09e+06     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 17            |
# |    iterations           | 139           |
# |    time_elapsed         | 782           |
# |    total_timesteps      | 13900         |
# | train/                  |               |
# |    approx_kl            | 8.2612036e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.78         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.36e+06      |
# |    n_updates            | 3380          |
# |    policy_gradient_loss | -0.00028      |
# |    value_loss           | 4.72e+06      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 17            |
# |    iterations           | 140           |
# |    time_elapsed         | 792           |
# |    total_timesteps      | 14000         |
# | train/                  |               |
# |    approx_kl            | 6.6936013e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.78         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.43e+06      |
# |    n_updates            | 3390          |
# |    policy_gradient_loss | -0.000268     |
# |    value_loss           | 6.86e+06      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 17            |
# |    iterations           | 141           |
# |    time_elapsed         | 801           |
# |    total_timesteps      | 14100         |
# | train/                  |               |
# |    approx_kl            | 1.6248226e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.78         |
# |    explained_variance   | -2.38e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.26e+06      |
# |    n_updates            | 3400          |
# |    policy_gradient_loss | -0.00053      |
# |    value_loss           | 2.53e+06      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 17            |
# |    iterations           | 142           |
# |    time_elapsed         | 810           |
# |    total_timesteps      | 14200         |
# | train/                  |               |
# |    approx_kl            | 1.7541646e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.78         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 8e+05         |
# |    n_updates            | 3410          |
# |    policy_gradient_loss | -0.000565     |
# |    value_loss           | 1.6e+06       |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 17            |
# |    iterations           | 143           |
# |    time_elapsed         | 819           |
# |    total_timesteps      | 14300         |
# | train/                  |               |
# |    approx_kl            | 1.1396407e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.78         |
# |    explained_variance   | 1.19e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 6.89e+06      |
# |    n_updates            | 3420          |
# |    policy_gradient_loss | -0.000174     |
# |    value_loss           | 1.38e+07      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 17           |
# |    iterations           | 144          |
# |    time_elapsed         | 829          |
# |    total_timesteps      | 14400        |
# | train/                  |              |
# |    approx_kl            | 4.172325e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.78        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.59e+06     |
# |    n_updates            | 3430         |
# |    policy_gradient_loss | -0.000226    |
# |    value_loss           | 7.19e+06     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 17           |
# |    iterations           | 145          |
# |    time_elapsed         | 839          |
# |    total_timesteps      | 14500        |
# | train/                  |              |
# |    approx_kl            | 8.654594e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.78        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.79e+06     |
# |    n_updates            | 3440         |
# |    policy_gradient_loss | -0.00033     |
# |    value_loss           | 5.58e+06     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 17            |
# |    iterations           | 146           |
# |    time_elapsed         | 849           |
# |    total_timesteps      | 14600         |
# | train/                  |               |
# |    approx_kl            | 1.6075372e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.78         |
# |    explained_variance   | 1.19e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 9.29e+05      |
# |    n_updates            | 3450          |
# |    policy_gradient_loss | -0.000477     |
# |    value_loss           | 1.86e+06      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 17            |
# |    iterations           | 147           |
# |    time_elapsed         | 860           |
# |    total_timesteps      | 14700         |
# | train/                  |               |
# |    approx_kl            | 1.6111135e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.78         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.72e+06      |
# |    n_updates            | 3460          |
# |    policy_gradient_loss | -0.000559     |
# |    value_loss           | 3.44e+06      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 17            |
# |    iterations           | 148           |
# |    time_elapsed         | 870           |
# |    total_timesteps      | 14800         |
# | train/                  |               |
# |    approx_kl            | 1.4334917e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.78         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.26e+06      |
# |    n_updates            | 3470          |
# |    policy_gradient_loss | -0.00042      |
# |    value_loss           | 2.52e+06      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 16            |
# |    iterations           | 149           |
# |    time_elapsed         | 881           |
# |    total_timesteps      | 14900         |
# | train/                  |               |
# |    approx_kl            | 1.1754036e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.78         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.98e+06      |
# |    n_updates            | 3480          |
# |    policy_gradient_loss | -0.000406     |
# |    value_loss           | 3.96e+06      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 16            |
# |    iterations           | 150           |
# |    time_elapsed         | 891           |
# |    total_timesteps      | 15000         |
# | train/                  |               |
# |    approx_kl            | 1.5819072e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.78         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.36e+06      |
# |    n_updates            | 3490          |
# |    policy_gradient_loss | -0.000481     |
# |    value_loss           | 2.71e+06      |
# -------------------------------------------

# %%
# double check that the network parameters are changing, add an assert
# move to py file and schedule batch job with A100
# use the networks that are built to predict yhats and plot the graph (visual representation of learning)

# %%
# (2, 20)
yhats = model.yhats_by_epoch_by_task
indices = model.layerindices_by_epoch_by_task
actions = model.actions_taken_by_epoch_by_task
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[313], line 2
#       1 # (2, 20)
# ----> 2 yhats = model.yhats_by_epoch_by_task
#       3 indices = model.layerindices_by_epoch_by_task
#       4 actions = model.actions_taken_by_epoch_by_task
#
# AttributeError: 'REML' object has no attribute 'yhats_by_epoch_by_task'

# %%
# # yhats
# # x is task
# # y is loss per task averaged over epochs
# plt.xlabel('task')
# plt.ylabel('MSE loss')
# plt.title('MSE per task (2 epochs)')

# # calculate loss values as average for the task for the epoch
# loss_by_task = []
# for (epoch, epoch_dict) in yhats.items(): # 2 epochs
#     epoch_vals = []
#     for task, (key, yhat_values) in zip(tasks, epoch_dict.items()): # 20 tasks
#         # key is task id, which is string of task_info
#         # value is list of yhats or list of tensors
#         losses_by_task = [] 
#         for y, yhat in zip(task.targets, yhat_values):
#             loss = F.mse_loss(y.unsqueeze(0), yhat.unsqueeze(0))
#             loss = loss.detach().numpy()
#             losses_by_task.append(loss)
#         loss_by_task.append(sum(losses_by_task) / len(losses_by_task))
    
# loss_by_epoch_by_task = np.array(loss_by_epoch_by_task)
# print(f'loss_by_epoch_by_task shape={loss_by_epoch_by_task.shape}')

# #         losses = []
# #         for y, y_hat in zip(data[1], y_hats): # 100 values
# #             y_hat = y_hat.unsqueeze(0)
# #             y = torch.tensor(y).unsqueeze(0) # can't iterate over 0d tensors
# #             loss = F.mse_loss(y, y_hat)
# #             losses.append(loss)
# #     loss_by_task.append( (sum(losses)/len(losses)).detach().numpy() ) # can't plot tensor values
# # print(loss_by_task)

# plt.scatter(
#     range(1, config['N_TASKS'] + 1), 
#     loss_by_task
#     )
# Out:
# C:\Users\stach\AppData\Local\Temp\ipykernel_12716\4051386411.py:17: UserWarning: Using a target size (torch.Size([1, 1])) that is different to the input size (torch.Size([1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   loss = F.mse_loss(y.unsqueeze(0), yhat.unsqueeze(0))
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 22
#      19             losses_by_task.append(loss)
#      20         loss_by_task.append(sum(losses_by_task) / len(losses_by_task))
# ---> 22 loss_by_epoch_by_task = np.array(loss_by_epoch_by_task)
#      23 print(f'loss_by_epoch_by_task shape={loss_by_epoch_by_task.shape}')
#      25 #         losses = []
#      26 #         for y, y_hat in zip(data[1], y_hats): # 100 values
#      27 #             y_hat = y_hat.unsqueeze(0)
#    (...)
#      31 #     loss_by_task.append( (sum(losses)/len(losses)).detach().numpy() ) # can't plot tensor values
#      32 # print(loss_by_task)
#
# NameError: name 'loss_by_epoch_by_task' is not defined

# %%
# plot layer use for all tasks
plt.xlabel('layer')
plt.ylabel('usage count')
plt.title('layer usage histogram (1 epoch)')
plt.scatter(
    range(N_X), 
    [layer.times_used for layer in pool.layers.values()]
    );

# %% [markdown]
# ### Loss w/ transfer vs. w/o transfer

# %%
# PRINT PLOTS
rows = 2
cols = 4
fig, axs = plt.subplots(rows, cols, sharex=True, sharey=True, figsize=(8,15))
k = 0
for i in range(rows):
    for j in range(cols):
        task = list(task_to_yhats.keys())[k]
        y_hats = task_to_yhats[task]
        axs[i, j].plot(X, [y_hat.detach().numpy() for y_hat in y_hats])
        axs[i, j].plot(X, list(tasks.items())[k][1])
        axs[i,j].set_title(task)
        k+=1
